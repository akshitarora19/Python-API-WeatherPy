# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
# %matplotlib notebook

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Output File (CSV)
output_data_file = "cities-Copy.csv"

# Exporting list of cities to csv file
with open (output_data_file, "w", newline='') as cities_file:
    city_data=csv.writer(cities_file, delimiter=",")
    for city in cities:
        city_data.writerow(city)

# %%
url= "https://api.openweathermap.org/data/2.5/weather?"
units="metric"

for city in cities:
    query_url = f"{url}appid={api_key}&units={units}&q={city}"

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    try:
        response = requests.get(f"{url}appid={api_key}&units={units}&q={city}").json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Saint John
# https://api.openweathermap.org/data/2.5/weather?&q=saint john
# Processing Record 2 | Naze
# https://api.openweathermap.org/data/2.5/weather?&q=naze
# Processing Record 3 | Mahebourg
# https://api.openweathermap.org/data/2.5/weather?&q=mahebourg
# Processing Record 4 | Ushuaia
# https://api.openweathermap.org/data/2.5/weather?&q=ushuaia
# Processing Record 5 | Cleethorpes
# https://api.openweathermap.org/data/2.5/weather?&q=cleethorpes
# Processing Record 6 | Hilo
# https://api.openweathermap.org/data/2.5/weather?&q=hilo
# Processing Record 7 | Atuona
# https://api.openweathermap.org/data/2.5/weather?&q=atuona
# Processing Record 8 | Iisalmi
# https://api.openweathermap.org/data/2.5/weather?&q=iisalmi
# Processing Record 9 | Busselton
# https://api.openweathermap.org/data/2.5/weather?&q=busselton
# Processing Record 10 | Barrow
# https://api.openweathermap.org/data/2.5/weather?&q=barrow
# Processing Record 11 | Namatanai
# https://api.openweathermap.org/data/2.5/weather?&q=namatanai
# Processing Record 12 | Rikitea
# https://api.openweathermap.org/data/2.5/weather?&q=rikitea
# Processing Record 13 | Oudtshoorn
# https://api.openweathermap.org/data/2.5/weather?&q=oudtshoorn
# City not found. Skipping...
# Processing Record 14 | Areka
# https://api.openweathermap.org/data/2.5/weather?&q=areka
# Processing Record 15 | Fortuna
# https://api.openweathermap.org/data/2.5/weather?&q=fortuna
# Processing Record 16 | Alabaster
# https://api.openweathermap.org/data/2.5/weather?&q=alabaster
# Processing Record 17 | Avarua
# https://api.openweathermap.org/data/2.5/weather?&q=avarua
# Processing Record 18 | Taltal
# https://api.openweathermap.org/data/2.5/weather?&q=taltal
# Processing Record 19 | Jamestown
# https://api.openweathermap.org/data/2.5/weather?&q=jamestown
# Processing Record 20 | Kenora
# https://api.openweathermap.org/data/2.5/weather?&q=kenora
# Processing Record 21 | Jieshi
# https://api.openweathermap.org/data/2.5/weather?&q=jieshi
# Processing Record 22 | Tabou
# https://api.openweathermap.org/data/2.5/weather?&q=tabou
# Processing Record 23 | Mataura
# https://api.openweathermap.org/data/2.5/weather?&q=mataura
# Processing Record 24 | Bida
# https://api.openweathermap.org/data/2.5/weather?&q=bida
# Processing Record 25 | Albany
# https://api.openweathermap.org/data/2.5/weather?&q=albany
# Processing Record 26 | Punta Arenas
# https://api.openweathermap.org/data/2.5/weather?&q=punta arenas
# Processing Record 27 | Tsimlyansk
# https://api.openweathermap.org/data/2.5/weather?&q=tsimlyansk
# Processing Record 28 | Guerrero Negro
# https://api.openweathermap.org/data/2.5/weather?&q=guerrero negro
# Processing Record 29 | Floro
# https://api.openweathermap.org/data/2.5/weather?&q=floro
# Processing Record 30 | Ribeira Grande
# https://api.openweathermap.org/data/2.5/weather?&q=ribeira grande
# Processing Record 31 | Margate
# https://api.openweathermap.org/data/2.5/weather?&q=margate
# Processing Record 32 | San Luis
# https://api.openweathermap.org/data/2.5/weather?&q=san luis
# Processing Record 33 | Hermanus
# https://api.openweathermap.org/data/2.5/weather?&q=hermanus
# Processing Record 34 | Santa Isabel do Rio Negro
# https://api.openweathermap.org/data/2.5/weather?&q=santa isabel do rio negro
# Processing Record 35 | Ponta do Sol
# https://api.openweathermap.org/data/2.5/weather?&q=ponta do sol
# Processing Record 36 | Czluchow
# https://api.openweathermap.org/data/2.5/weather?&q=czluchow
# Processing Record 37 | Aklavik
# https://api.openweathermap.org/data/2.5/weather?&q=aklavik
# Processing Record 38 | Hobart
# https://api.openweathermap.org/data/2.5/weather?&q=hobart
# Processing Record 39 | Yellowknife
# https://api.openweathermap.org/data/2.5/weather?&q=yellowknife
# City not found. Skipping...
# Processing Record 40 | High Level
# https://api.openweathermap.org/data/2.5/weather?&q=high level
# Processing Record 41 | Pilar
# https://api.openweathermap.org/data/2.5/weather?&q=pilar
# City not found. Skipping...
# Processing Record 42 | Tuktoyaktuk
# https://api.openweathermap.org/data/2.5/weather?&q=tuktoyaktuk
# City not found. Skipping...
# Processing Record 43 | Ewa Beach
# https://api.openweathermap.org/data/2.5/weather?&q=ewa beach
# Processing Record 44 | Torbay
# https://api.openweathermap.org/data/2.5/weather?&q=torbay
# Processing Record 45 | Cape Town
# https://api.openweathermap.org/data/2.5/weather?&q=cape town
# Processing Record 46 | Evensk
# https://api.openweathermap.org/data/2.5/weather?&q=evensk
# Processing Record 47 | Saldanha
# https://api.openweathermap.org/data/2.5/weather?&q=saldanha
# Processing Record 48 | Saint-Philippe
# https://api.openweathermap.org/data/2.5/weather?&q=saint-philippe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 | Rocha
# https://api.openweathermap.org/data/2.5/weather?&q=rocha
# Processing Record 50 | Kathmandu
# https://api.openweathermap.org/data/2.5/weather?&q=kathmandu
# Processing Record 51 | Rock Sound
# https://api.openweathermap.org/data/2.5/weather?&q=rock sound
# Processing Record 52 | Carnarvon
# https://api.openweathermap.org/data/2.5/weather?&q=carnarvon
# City not found. Skipping...
# Processing Record 53 | Cecina
# https://api.openweathermap.org/data/2.5/weather?&q=cecina
# Processing Record 54 | Port Alfred
# https://api.openweathermap.org/data/2.5/weather?&q=port alfred
# Processing Record 55 | Pangnirtung
# https://api.openweathermap.org/data/2.5/weather?&q=pangnirtung
# Processing Record 56 | Vaini
# https://api.openweathermap.org/data/2.5/weather?&q=vaini
# Processing Record 57 | Braganca
# https://api.openweathermap.org/data/2.5/weather?&q=braganca
# Processing Record 58 | Puri
# https://api.openweathermap.org/data/2.5/weather?&q=puri
# Processing Record 59 | Pouebo
# https://api.openweathermap.org/data/2.5/weather?&q=pouebo
# Processing Record 60 | Butaritari
# https://api.openweathermap.org/data/2.5/weather?&q=butaritari
# Processing Record 61 | Ilulissat
# https://api.openweathermap.org/data/2.5/weather?&q=ilulissat
# Processing Record 62 | Tiksi
# https://api.openweathermap.org/data/2.5/weather?&q=tiksi
# Processing Record 63 | Thompson
# https://api.openweathermap.org/data/2.5/weather?&q=thompson
# City not found. Skipping...
# Processing Record 64 | Upernavik
# https://api.openweathermap.org/data/2.5/weather?&q=upernavik
# Processing Record 65 | Puerto Ayora
# https://api.openweathermap.org/data/2.5/weather?&q=puerto ayora
# Processing Record 66 | Chumikan
# https://api.openweathermap.org/data/2.5/weather?&q=chumikan
# Processing Record 67 | Constitucion
# https://api.openweathermap.org/data/2.5/weather?&q=constitucion
# Processing Record 68 | Auki
# https://api.openweathermap.org/data/2.5/weather?&q=auki
# Processing Record 69 | Tezu
# https://api.openweathermap.org/data/2.5/weather?&q=tezu
# Processing Record 70 | Hasaki
# https://api.openweathermap.org/data/2.5/weather?&q=hasaki
# City not found. Skipping...
# Processing Record 71 | Poya
# https://api.openweathermap.org/data/2.5/weather?&q=poya
# Processing Record 72 | Manakara
# https://api.openweathermap.org/data/2.5/weather?&q=manakara
# Processing Record 73 | Karratha
# https://api.openweathermap.org/data/2.5/weather?&q=karratha
# Processing Record 74 | Cabo San Lucas
# https://api.openweathermap.org/data/2.5/weather?&q=cabo san lucas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 75 | San Patricio
# https://api.openweathermap.org/data/2.5/weather?&q=san patricio
# Processing Record 76 | Awbari
# https://api.openweathermap.org/data/2.5/weather?&q=awbari
# Processing Record 77 | Ginir
# https://api.openweathermap.org/data/2.5/weather?&q=ginir
# Processing Record 78 | Lagoa
# https://api.openweathermap.org/data/2.5/weather?&q=lagoa
# Processing Record 79 | Ilinge
# https://api.openweathermap.org/data/2.5/weather?&q=ilinge
# Processing Record 80 | Tasiilaq
# https://api.openweathermap.org/data/2.5/weather?&q=tasiilaq
# Processing Record 81 | Lipin Bor
# https://api.openweathermap.org/data/2.5/weather?&q=lipin bor
# Processing Record 82 | Jegunovce
# https://api.openweathermap.org/data/2.5/weather?&q=jegunovce
# Processing Record 83 | Najran
# https://api.openweathermap.org/data/2.5/weather?&q=najran
# Processing Record 84 | Bambous Virieux
# https://api.openweathermap.org/data/2.5/weather?&q=bambous virieux
# Processing Record 85 | Roald
# https://api.openweathermap.org/data/2.5/weather?&q=roald
# City not found. Skipping...
# Processing Record 86 | Hami
# https://api.openweathermap.org/data/2.5/weather?&q=hami
# Processing Record 87 | Matagami
# https://api.openweathermap.org/data/2.5/weather?&q=matagami
# Processing Record 88 | Buala
# https://api.openweathermap.org/data/2.5/weather?&q=buala
# Processing Record 89 | Qaanaaq
# https://api.openweathermap.org/data/2.5/weather?&q=qaanaaq
# Processing Record 90 | Kutum
# https://api.openweathermap.org/data/2.5/weather?&q=kutum
# City not found. Skipping...
# Processing Record 91 | Hovd
# https://api.openweathermap.org/data/2.5/weather?&q=hovd
# Processing Record 92 | Am Timan
# https://api.openweathermap.org/data/2.5/weather?&q=am timan
# Processing Record 93 | Sydney
# https://api.openweathermap.org/data/2.5/weather?&q=sydney
# Processing Record 94 | Waingapu
# https://api.openweathermap.org/data/2.5/weather?&q=waingapu
# Processing Record 95 | Mar del Plata
# https://api.openweathermap.org/data/2.5/weather?&q=mar del plata
# Processing Record 96 | Meadow Lake
# https://api.openweathermap.org/data/2.5/weather?&q=meadow lake
# Processing Record 97 | Kapaa
# https://api.openweathermap.org/data/2.5/weather?&q=kapaa
# Processing Record 98 | Cherskiy
# https://api.openweathermap.org/data/2.5/weather?&q=cherskiy
# City not found. Skipping...
# Processing Record 99 | Carmo
# https://api.openweathermap.org/data/2.5/weather?&q=carmo
# City not found. Skipping...
# Processing Record 100 | Lamu
# https://api.openweathermap.org/data/2.5/weather?&q=lamu
# Processing Record 101 | Cockburn Town
# https://api.openweathermap.org/data/2.5/weather?&q=cockburn town
# Processing Record 102 | Airai
# https://api.openweathermap.org/data/2.5/weather?&q=airai
# Processing Record 103 | Bredasdorp
# https://api.openweathermap.org/data/2.5/weather?&q=bredasdorp
# Processing Record 104 | Montemorelos
# https://api.openweathermap.org/data/2.5/weather?&q=montemorelos
# Processing Record 105 | Lake City
# https://api.openweathermap.org/data/2.5/weather?&q=lake city
# Processing Record 106 | Leh
# https://api.openweathermap.org/data/2.5/weather?&q=leh
# Processing Record 107 | Banfora
# https://api.openweathermap.org/data/2.5/weather?&q=banfora
# Processing Record 108 | Hithadhoo
# https://api.openweathermap.org/data/2.5/weather?&q=hithadhoo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 109 | Okhotsk
# https://api.openweathermap.org/data/2.5/weather?&q=okhotsk
# Processing Record 110 | Victoria
# https://api.openweathermap.org/data/2.5/weather?&q=victoria
# Processing Record 111 | Verin
# https://api.openweathermap.org/data/2.5/weather?&q=verin
# Processing Record 112 | Paamiut
# https://api.openweathermap.org/data/2.5/weather?&q=paamiut
# Processing Record 113 | Vestmannaeyjar
# https://api.openweathermap.org/data/2.5/weather?&q=vestmannaeyjar
# Processing Record 114 | Camacha
# https://api.openweathermap.org/data/2.5/weather?&q=camacha
# City not found. Skipping...
# Processing Record 115 | Codrington
# https://api.openweathermap.org/data/2.5/weather?&q=codrington
# Processing Record 116 | Vila do Maio
# https://api.openweathermap.org/data/2.5/weather?&q=vila do maio
# Processing Record 117 | Nikolskoye
# https://api.openweathermap.org/data/2.5/weather?&q=nikolskoye
# Processing Record 118 | Meulaboh
# https://api.openweathermap.org/data/2.5/weather?&q=meulaboh
# Processing Record 119 | Bluff
# https://api.openweathermap.org/data/2.5/weather?&q=bluff
# Processing Record 120 | Mutoko
# https://api.openweathermap.org/data/2.5/weather?&q=mutoko
# Processing Record 121 | Longyearbyen
# https://api.openweathermap.org/data/2.5/weather?&q=longyearbyen
# Processing Record 122 | Adrar
# https://api.openweathermap.org/data/2.5/weather?&q=adrar
# City not found. Skipping...
# Processing Record 123 | Mazyr
# https://api.openweathermap.org/data/2.5/weather?&q=mazyr
# Processing Record 124 | Shimoda
# https://api.openweathermap.org/data/2.5/weather?&q=shimoda
# Processing Record 125 | Arraial do Cabo
# https://api.openweathermap.org/data/2.5/weather?&q=arraial do cabo
# Processing Record 126 | Zhezkazgan
# https://api.openweathermap.org/data/2.5/weather?&q=zhezkazgan
# Processing Record 127 | Moerai
# https://api.openweathermap.org/data/2.5/weather?&q=moerai
# City not found. Skipping...
# Processing Record 128 | East London
# https://api.openweathermap.org/data/2.5/weather?&q=east london
# Processing Record 129 | Nanchang
# https://api.openweathermap.org/data/2.5/weather?&q=nanchang
# Processing Record 130 | Pacifica
# https://api.openweathermap.org/data/2.5/weather?&q=pacifica
# Processing Record 131 | Podor
# https://api.openweathermap.org/data/2.5/weather?&q=podor
# City not found. Skipping...
# Processing Record 132 | Bonavista
# https://api.openweathermap.org/data/2.5/weather?&q=bonavista
# Processing Record 133 | Grindavik
# https://api.openweathermap.org/data/2.5/weather?&q=grindavik
# City not found. Skipping...
# Processing Record 134 | Sobolevo
# https://api.openweathermap.org/data/2.5/weather?&q=sobolevo
# Processing Record 135 | Lebu
# https://api.openweathermap.org/data/2.5/weather?&q=lebu
# Processing Record 136 | Carutapera
# https://api.openweathermap.org/data/2.5/weather?&q=carutapera
# Processing Record 137 | Ozernovskiy
# https://api.openweathermap.org/data/2.5/weather?&q=ozernovskiy
# Processing Record 138 | Terney
# https://api.openweathermap.org/data/2.5/weather?&q=terney
# Processing Record 139 | Pitelino
# https://api.openweathermap.org/data/2.5/weather?&q=pitelino
# Processing Record 140 | Pevek
# https://api.openweathermap.org/data/2.5/weather?&q=pevek
# Processing Record 141 | Klyuchi
# https://api.openweathermap.org/data/2.5/weather?&q=klyuchi
# Processing Record 142 | Lavrentiya
# https://api.openweathermap.org/data/2.5/weather?&q=lavrentiya
# Processing Record 143 | Port Elizabeth
# https://api.openweathermap.org/data/2.5/weather?&q=port elizabeth
# Processing Record 144 | Linjiang
# https://api.openweathermap.org/data/2.5/weather?&q=linjiang
# Processing Record 145 | Raudeberg
# https://api.openweathermap.org/data/2.5/weather?&q=raudeberg
# Processing Record 146 | Mount Isa
# https://api.openweathermap.org/data/2.5/weather?&q=mount isa
# Processing Record 147 | Ivdel
# https://api.openweathermap.org/data/2.5/weather?&q=ivdel
# Processing Record 148 | Siyabuswa
# https://api.openweathermap.org/data/2.5/weather?&q=siyabuswa
# Processing Record 149 | Kushiro
# https://api.openweathermap.org/data/2.5/weather?&q=kushiro
# City not found. Skipping...
# Processing Record 150 | Porto Nacional
# https://api.openweathermap.org/data/2.5/weather?&q=porto nacional
# Processing Record 151 | Harare
# https://api.openweathermap.org/data/2.5/weather?&q=harare
# Processing Record 152 | Sao Filipe
# https://api.openweathermap.org/data/2.5/weather?&q=sao filipe
# Processing Record 153 | Denpasar
# https://api.openweathermap.org/data/2.5/weather?&q=denpasar
# Processing Record 154 | Provideniya
# https://api.openweathermap.org/data/2.5/weather?&q=provideniya
# Processing Record 155 | New Norfolk
# https://api.openweathermap.org/data/2.5/weather?&q=new norfolk
# Processing Record 156 | Port Lincoln
# https://api.openweathermap.org/data/2.5/weather?&q=port lincoln
# Processing Record 157 | Kavaratti
# https://api.openweathermap.org/data/2.5/weather?&q=kavaratti
# Processing Record 158 | Brokopondo
# https://api.openweathermap.org/data/2.5/weather?&q=brokopondo
# Processing Record 159 | Xinqing
# https://api.openweathermap.org/data/2.5/weather?&q=xinqing
# Processing Record 160 | Georgetown
# https://api.openweathermap.org/data/2.5/weather?&q=georgetown
# Processing Record 161 | Geraldton
# https://api.openweathermap.org/data/2.5/weather?&q=geraldton
# Processing Record 162 | Lompoc
# https://api.openweathermap.org/data/2.5/weather?&q=lompoc
# Processing Record 163 | Port Hardy
# https://api.openweathermap.org/data/2.5/weather?&q=port hardy
# Processing Record 164 | Kidal
# https://api.openweathermap.org/data/2.5/weather?&q=kidal
# Processing Record 165 | Bowen
# https://api.openweathermap.org/data/2.5/weather?&q=bowen
# Processing Record 166 | Ehingen
# https://api.openweathermap.org/data/2.5/weather?&q=ehingen
# Processing Record 167 | Husavik
# https://api.openweathermap.org/data/2.5/weather?&q=husavik
# Processing Record 168 | Umkomaas
# https://api.openweathermap.org/data/2.5/weather?&q=umkomaas
# Processing Record 169 | Mehamn
# https://api.openweathermap.org/data/2.5/weather?&q=mehamn
# Processing Record 170 | Ayr
# https://api.openweathermap.org/data/2.5/weather?&q=ayr
# Processing Record 171 | Impfondo
# https://api.openweathermap.org/data/2.5/weather?&q=impfondo
# Processing Record 172 | Saint George
# https://api.openweathermap.org/data/2.5/weather?&q=saint george
# Processing Record 173 | Xiongzhou
# https://api.openweathermap.org/data/2.5/weather?&q=xiongzhou
# Processing Record 174 | Pontes e Lacerda
# https://api.openweathermap.org/data/2.5/weather?&q=pontes e lacerda
# Processing Record 175 | Akron
# https://api.openweathermap.org/data/2.5/weather?&q=akron
# Processing Record 176 | Dhekiajuli
# https://api.openweathermap.org/data/2.5/weather?&q=dhekiajuli
# Processing Record 177 | Eydhafushi
# https://api.openweathermap.org/data/2.5/weather?&q=eydhafushi
# Processing Record 178 | Henties Bay
# https://api.openweathermap.org/data/2.5/weather?&q=henties bay
# Processing Record 179 | Kodiak
# https://api.openweathermap.org/data/2.5/weather?&q=kodiak
# Processing Record 180 | Chokurdakh
# https://api.openweathermap.org/data/2.5/weather?&q=chokurdakh
# Processing Record 181 | Paita
# https://api.openweathermap.org/data/2.5/weather?&q=paita
# Processing Record 182 | Altamira
# https://api.openweathermap.org/data/2.5/weather?&q=altamira
# Processing Record 183 | Faanui
# https://api.openweathermap.org/data/2.5/weather?&q=faanui
# Processing Record 184 | Russell
# https://api.openweathermap.org/data/2.5/weather?&q=russell
# Processing Record 185 | Praia da Vitoria
# https://api.openweathermap.org/data/2.5/weather?&q=praia da vitoria
# Processing Record 186 | Beruwala
# https://api.openweathermap.org/data/2.5/weather?&q=beruwala
# Processing Record 187 | Sola
# https://api.openweathermap.org/data/2.5/weather?&q=sola
# Processing Record 188 | Tiznit
# https://api.openweathermap.org/data/2.5/weather?&q=tiznit
# Processing Record 189 | Adelaide
# https://api.openweathermap.org/data/2.5/weather?&q=adelaide
# Processing Record 190 | Sivani
# https://api.openweathermap.org/data/2.5/weather?&q=seoni
# Processing Record 191 | Novi Bilokorovychi
# https://api.openweathermap.org/data/2.5/weather?&q=novi bilokorovychi
# Processing Record 192 | Kaitangata
# https://api.openweathermap.org/data/2.5/weather?&q=kaitangata
# Processing Record 193 | Weligama
# https://api.openweathermap.org/data/2.5/weather?&q=weligama
# Processing Record 194 | Sinnamary
# https://api.openweathermap.org/data/2.5/weather?&q=sinnamary
# Processing Record 195 | Itambacuri
# https://api.openweathermap.org/data/2.5/weather?&q=itambacuri
# Processing Record 196 | Fort Nelson
# https://api.openweathermap.org/data/2.5/weather?&q=fort nelson
# City not found. Skipping...
# Processing Record 197 | Chuy
# https://api.openweathermap.org/data/2.5/weather?&q=chuy
# Processing Record 198 | Beringovskiy
# https://api.openweathermap.org/data/2.5/weather?&q=beringovskiy
# Processing Record 199 | Nouadhibou
# https://api.openweathermap.org/data/2.5/weather?&q=nouadhibou
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 200 | Iqaluit
# https://api.openweathermap.org/data/2.5/weather?&q=iqaluit
# Processing Record 201 | Honningsvag
# https://api.openweathermap.org/data/2.5/weather?&q=honningsvag
# Processing Record 202 | Pathein
# https://api.openweathermap.org/data/2.5/weather?&q=pathein
# Processing Record 203 | Schaffhausen
# https://api.openweathermap.org/data/2.5/weather?&q=schaffhausen
# Processing Record 204 | Cidreira
# https://api.openweathermap.org/data/2.5/weather?&q=cidreira
# Processing Record 205 | Hualmay
# https://api.openweathermap.org/data/2.5/weather?&q=hualmay
# Processing Record 206 | Richards Bay
# https://api.openweathermap.org/data/2.5/weather?&q=richards bay
# Processing Record 207 | Berlevag
# https://api.openweathermap.org/data/2.5/weather?&q=berlevag
# Processing Record 208 | Zdolbuniv
# https://api.openweathermap.org/data/2.5/weather?&q=zdolbuniv
# Processing Record 209 | Noumea
# https://api.openweathermap.org/data/2.5/weather?&q=noumea
# City not found. Skipping...
# Processing Record 210 | Gorom-Gorom
# https://api.openweathermap.org/data/2.5/weather?&q=gorom-gorom
# Processing Record 211 | Klaksvik
# https://api.openweathermap.org/data/2.5/weather?&q=klaksvik
# Processing Record 212 | Mugur-Aksy
# https://api.openweathermap.org/data/2.5/weather?&q=mugur-aksy
# Processing Record 213 | Souillac
# https://api.openweathermap.org/data/2.5/weather?&q=souillac
# Processing Record 214 | West Bay
# https://api.openweathermap.org/data/2.5/weather?&q=west bay
# Processing Record 215 | Emerald
# https://api.openweathermap.org/data/2.5/weather?&q=emerald
# Processing Record 216 | Yulara
# https://api.openweathermap.org/data/2.5/weather?&q=yulara
# City not found. Skipping...
# Processing Record 217 | Shaki
# https://api.openweathermap.org/data/2.5/weather?&q=shaki
# Processing Record 218 | Paungde
# https://api.openweathermap.org/data/2.5/weather?&q=paungde
# Processing Record 219 | Westport
# https://api.openweathermap.org/data/2.5/weather?&q=westport
# Processing Record 220 | Yumen
# https://api.openweathermap.org/data/2.5/weather?&q=yumen
# Processing Record 221 | Jining
# https://api.openweathermap.org/data/2.5/weather?&q=jining
# Processing Record 222 | Salalah
# https://api.openweathermap.org/data/2.5/weather?&q=salalah
# Processing Record 223 | Nicoya
# https://api.openweathermap.org/data/2.5/weather?&q=nicoya
# Processing Record 224 | Tura
# https://api.openweathermap.org/data/2.5/weather?&q=tura
# Processing Record 225 | Port Macquarie
# https://api.openweathermap.org/data/2.5/weather?&q=port macquarie
# Processing Record 226 | Severo-Kurilsk
# https://api.openweathermap.org/data/2.5/weather?&q=severo-kurilsk
# Processing Record 227 | Havre-Saint-Pierre
# https://api.openweathermap.org/data/2.5/weather?&q=havre-saint-pierre
# Processing Record 228 | Castro
# https://api.openweathermap.org/data/2.5/weather?&q=castro
# Processing Record 229 | Champerico
# https://api.openweathermap.org/data/2.5/weather?&q=champerico
# Processing Record 230 | Itoman
# https://api.openweathermap.org/data/2.5/weather?&q=itoman
# Processing Record 231 | Lewiston
# https://api.openweathermap.org/data/2.5/weather?&q=lewiston
# Processing Record 232 | Egvekinot
# https://api.openweathermap.org/data/2.5/weather?&q=egvekinot
# Processing Record 233 | Sumbawanga
# https://api.openweathermap.org/data/2.5/weather?&q=sumbawanga
# Processing Record 234 | Valparaiso
# https://api.openweathermap.org/data/2.5/weather?&q=valparaiso
# Processing Record 235 | Shitanjing
# https://api.openweathermap.org/data/2.5/weather?&q=shitanjing
# Processing Record 236 | Maple Creek
# https://api.openweathermap.org/data/2.5/weather?&q=maple creek
# Processing Record 237 | Pinos
# https://api.openweathermap.org/data/2.5/weather?&q=pinos
# Processing Record 238 | Sarh
# https://api.openweathermap.org/data/2.5/weather?&q=sarh
# Processing Record 239 | Outjo
# https://api.openweathermap.org/data/2.5/weather?&q=outjo
# Processing Record 240 | Hambantota
# https://api.openweathermap.org/data/2.5/weather?&q=hambantota
# Processing Record 241 | Simao
# https://api.openweathermap.org/data/2.5/weather?&q=simao
# City not found. Skipping...
# Processing Record 242 | Alofi
# https://api.openweathermap.org/data/2.5/weather?&q=alofi
# Processing Record 243 | Sistranda
# https://api.openweathermap.org/data/2.5/weather?&q=sistranda
# Processing Record 244 | Jurm
# https://api.openweathermap.org/data/2.5/weather?&q=jurm
# Processing Record 245 | Walvis Bay
# https://api.openweathermap.org/data/2.5/weather?&q=walvis bay
# Processing Record 246 | Saskylakh
# https://api.openweathermap.org/data/2.5/weather?&q=saskylakh
# Processing Record 247 | Srednekolymsk
# https://api.openweathermap.org/data/2.5/weather?&q=srednekolymsk
# Processing Record 248 | Portland
# https://api.openweathermap.org/data/2.5/weather?&q=portland
# Processing Record 249 | Kodinsk
# https://api.openweathermap.org/data/2.5/weather?&q=kodinsk
# Processing Record 250 | Ahmadnagar
# https://api.openweathermap.org/data/2.5/weather?&q=ahmadnagar
# City not found. Skipping...
# Processing Record 251 | Kalmunai
# https://api.openweathermap.org/data/2.5/weather?&q=kalmunai
# Processing Record 252 | Sakaraha
# https://api.openweathermap.org/data/2.5/weather?&q=sakaraha
# Processing Record 253 | Comodoro Rivadavia
# https://api.openweathermap.org/data/2.5/weather?&q=comodoro rivadavia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 254 | Miandrivazo
# https://api.openweathermap.org/data/2.5/weather?&q=miandrivazo
# City not found. Skipping...
# Processing Record 255 | Taoudenni
# https://api.openweathermap.org/data/2.5/weather?&q=taoudenni
# Processing Record 256 | Balikpapan
# https://api.openweathermap.org/data/2.5/weather?&q=balikpapan
# Processing Record 257 | Ostrovnoy
# https://api.openweathermap.org/data/2.5/weather?&q=ostrovnoy
# Processing Record 258 | Namibe
# https://api.openweathermap.org/data/2.5/weather?&q=namibe
# Processing Record 259 | Mandera
# https://api.openweathermap.org/data/2.5/weather?&q=mandera
# Processing Record 260 | Ukiah
# https://api.openweathermap.org/data/2.5/weather?&q=ukiah
# Processing Record 261 | Labytnangi
# https://api.openweathermap.org/data/2.5/weather?&q=labytnangi
# City not found. Skipping...
# Processing Record 262 | Lorengau
# https://api.openweathermap.org/data/2.5/weather?&q=lorengau
# Processing Record 263 | Christchurch
# https://api.openweathermap.org/data/2.5/weather?&q=christchurch
# Processing Record 264 | Isangel
# https://api.openweathermap.org/data/2.5/weather?&q=isangel
# Processing Record 265 | Bremervorde
# https://api.openweathermap.org/data/2.5/weather?&q=bremervorde
# Processing Record 266 | Mabaruma
# https://api.openweathermap.org/data/2.5/weather?&q=mabaruma
# Processing Record 267 | Inyonga
# https://api.openweathermap.org/data/2.5/weather?&q=inyonga
# Processing Record 268 | Gasa
# https://api.openweathermap.org/data/2.5/weather?&q=gasa
# Processing Record 269 | Cururupu
# https://api.openweathermap.org/data/2.5/weather?&q=cururupu
# Processing Record 270 | Kalabo
# https://api.openweathermap.org/data/2.5/weather?&q=kalabo
# City not found. Skipping...
# Processing Record 271 | Berdigestyakh
# https://api.openweathermap.org/data/2.5/weather?&q=berdigestyakh
# Processing Record 272 | Aykhal
# https://api.openweathermap.org/data/2.5/weather?&q=aykhal
# City not found. Skipping...
# Processing Record 273 | Vanavara
# https://api.openweathermap.org/data/2.5/weather?&q=vanavara
# Processing Record 274 | Narsaq
# https://api.openweathermap.org/data/2.5/weather?&q=narsaq
# Processing Record 275 | Kruisfontein
# https://api.openweathermap.org/data/2.5/weather?&q=kruisfontein
# Processing Record 276 | Kihei
# https://api.openweathermap.org/data/2.5/weather?&q=kihei
# Processing Record 277 | Arsk
# https://api.openweathermap.org/data/2.5/weather?&q=arsk
# Processing Record 278 | Bako
# https://api.openweathermap.org/data/2.5/weather?&q=bako
# Processing Record 279 | Rodrigues Alves
# https://api.openweathermap.org/data/2.5/weather?&q=rodrigues alves
# City not found. Skipping...
# Processing Record 280 | Sauda
# https://api.openweathermap.org/data/2.5/weather?&q=sauda
# Processing Record 281 | Vao
# https://api.openweathermap.org/data/2.5/weather?&q=vao
# Processing Record 282 | Rudnogorsk
# https://api.openweathermap.org/data/2.5/weather?&q=rudnogorsk
# Processing Record 283 | Burnie
# https://api.openweathermap.org/data/2.5/weather?&q=burnie
# Processing Record 284 | Penapolis
# https://api.openweathermap.org/data/2.5/weather?&q=penapolis
# Processing Record 285 | Killam
# https://api.openweathermap.org/data/2.5/weather?&q=killam
# Processing Record 286 | Avola
# https://api.openweathermap.org/data/2.5/weather?&q=avola
# Processing Record 287 | Ugoofaaru
# https://api.openweathermap.org/data/2.5/weather?&q=ugoofaaru
# City not found. Skipping...
# Processing Record 288 | Bahia Honda
# https://api.openweathermap.org/data/2.5/weather?&q=bahia honda
# Processing Record 289 | Talnakh
# https://api.openweathermap.org/data/2.5/weather?&q=talnakh
# Processing Record 290 | Bayir
# https://api.openweathermap.org/data/2.5/weather?&q=bayir
# Processing Record 291 | Carman
# https://api.openweathermap.org/data/2.5/weather?&q=carman
# Processing Record 292 | Eureka
# https://api.openweathermap.org/data/2.5/weather?&q=eureka
# Processing Record 293 | Canto do Buriti
# https://api.openweathermap.org/data/2.5/weather?&q=canto do buriti
# Processing Record 294 | Joshimath
# https://api.openweathermap.org/data/2.5/weather?&q=joshimath
# Processing Record 295 | Touros
# https://api.openweathermap.org/data/2.5/weather?&q=touros
# Processing Record 296 | Coahuayana
# https://api.openweathermap.org/data/2.5/weather?&q=coahuayana
# Processing Record 297 | Hornepayne
# https://api.openweathermap.org/data/2.5/weather?&q=hornepayne
# Processing Record 298 | Rawson
# https://api.openweathermap.org/data/2.5/weather?&q=rawson
# Processing Record 299 | Mao
# https://api.openweathermap.org/data/2.5/weather?&q=mao
# Processing Record 300 | Port Moresby
# https://api.openweathermap.org/data/2.5/weather?&q=port moresby
# Processing Record 301 | Acandi
# https://api.openweathermap.org/data/2.5/weather?&q=acandi
# Processing Record 302 | Dikson
# https://api.openweathermap.org/data/2.5/weather?&q=dikson
# Processing Record 303 | Kavieng
# https://api.openweathermap.org/data/2.5/weather?&q=kavieng
# Processing Record 304 | Salinopolis
# https://api.openweathermap.org/data/2.5/weather?&q=salinopolis
# Processing Record 305 | Zhuhai
# https://api.openweathermap.org/data/2.5/weather?&q=zhuhai
# Processing Record 306 | Rio Gallegos
# https://api.openweathermap.org/data/2.5/weather?&q=rio gallegos
# Processing Record 307 | Bethel
# https://api.openweathermap.org/data/2.5/weather?&q=bethel
# Processing Record 308 | Kattivakkam
# https://api.openweathermap.org/data/2.5/weather?&q=kattivakkam
# Processing Record 309 | Martapura
# https://api.openweathermap.org/data/2.5/weather?&q=martapura
# Processing Record 310 | Vila Velha
# https://api.openweathermap.org/data/2.5/weather?&q=vila velha
# Processing Record 311 | Chicama
# https://api.openweathermap.org/data/2.5/weather?&q=chicama
# Processing Record 312 | Chabahar
# https://api.openweathermap.org/data/2.5/weather?&q=chabahar
# Processing Record 313 | Camopi
# https://api.openweathermap.org/data/2.5/weather?&q=camopi
# Processing Record 314 | Bonga
# https://api.openweathermap.org/data/2.5/weather?&q=bonga
# Processing Record 315 | Hun
# https://api.openweathermap.org/data/2.5/weather?&q=hun
# City not found. Skipping...
# Processing Record 316 | Kahului
# https://api.openweathermap.org/data/2.5/weather?&q=kahului
# Processing Record 317 | Puerto del Rosario
# https://api.openweathermap.org/data/2.5/weather?&q=puerto del rosario
# Processing Record 318 | Khatanga
# https://api.openweathermap.org/data/2.5/weather?&q=khatanga
# City not found. Skipping...
# Processing Record 319 | Norman Wells
# https://api.openweathermap.org/data/2.5/weather?&q=norman wells
# Processing Record 320 | Nantucket
# https://api.openweathermap.org/data/2.5/weather?&q=nantucket
# Processing Record 321 | Sterling
# https://api.openweathermap.org/data/2.5/weather?&q=sterling
# Processing Record 322 | Coquimbo
# https://api.openweathermap.org/data/2.5/weather?&q=coquimbo
# Processing Record 323 | Atyrau
# https://api.openweathermap.org/data/2.5/weather?&q=atyrau
# Processing Record 324 | Curumani
# https://api.openweathermap.org/data/2.5/weather?&q=curumani
# City not found. Skipping...
# Processing Record 325 | Goiatuba
# https://api.openweathermap.org/data/2.5/weather?&q=goiatuba
# Processing Record 326 | Pueblo
# https://api.openweathermap.org/data/2.5/weather?&q=pueblo
# City not found. Skipping...
# Processing Record 327 | San Jeronimo
# https://api.openweathermap.org/data/2.5/weather?&q=san jeronimo
# City not found. Skipping...
# Processing Record 328 | Sao Joao da Barra
# https://api.openweathermap.org/data/2.5/weather?&q=sao joao da barra
# Processing Record 329 | Toktogul
# https://api.openweathermap.org/data/2.5/weather?&q=toktogul
# Processing Record 330 | The Valley
# https://api.openweathermap.org/data/2.5/weather?&q=the valley
# Processing Record 331 | Juegang
# https://api.openweathermap.org/data/2.5/weather?&q=juegang
# Processing Record 332 | Dubbo
# https://api.openweathermap.org/data/2.5/weather?&q=dubbo
# Processing Record 333 | Mitsamiouli
# https://api.openweathermap.org/data/2.5/weather?&q=mitsamiouli
# Processing Record 334 | Ahipara
# https://api.openweathermap.org/data/2.5/weather?&q=ahipara
# Processing Record 335 | Trenggalek
# https://api.openweathermap.org/data/2.5/weather?&q=trenggalek
# Processing Record 336 | Bhinmal
# https://api.openweathermap.org/data/2.5/weather?&q=bhinmal
# Processing Record 337 | Coihaique
# https://api.openweathermap.org/data/2.5/weather?&q=coihaique
# Processing Record 338 | Lykhivka
# https://api.openweathermap.org/data/2.5/weather?&q=lykhivka
# Processing Record 339 | Sao Jose da Coroa Grande
# https://api.openweathermap.org/data/2.5/weather?&q=sao jose da coroa grande
# Processing Record 340 | Hailar
# https://api.openweathermap.org/data/2.5/weather?&q=hailar
# Processing Record 341 | Yinchuan
# https://api.openweathermap.org/data/2.5/weather?&q=yinchuan
# City not found. Skipping...
# Processing Record 342 | Diffa
# https://api.openweathermap.org/data/2.5/weather?&q=diffa
# Processing Record 343 | Ketchikan
# https://api.openweathermap.org/data/2.5/weather?&q=ketchikan
# Processing Record 344 | Broome
# https://api.openweathermap.org/data/2.5/weather?&q=broome
# Processing Record 345 | Leningradskiy
# https://api.openweathermap.org/data/2.5/weather?&q=leningradskiy
# Processing Record 346 | Sindal
# https://api.openweathermap.org/data/2.5/weather?&q=sindal
# Processing Record 347 | Sakaiminato
# https://api.openweathermap.org/data/2.5/weather?&q=sakaiminato
# Processing Record 348 | Brae
# https://api.openweathermap.org/data/2.5/weather?&q=brae
# Processing Record 349 | Gat
# https://api.openweathermap.org/data/2.5/weather?&q=gat
# Processing Record 350 | Juneau
# https://api.openweathermap.org/data/2.5/weather?&q=juneau
# Processing Record 351 | Saint-Augustin
# https://api.openweathermap.org/data/2.5/weather?&q=saint-augustin
# Processing Record 352 | Ust-Tarka
# https://api.openweathermap.org/data/2.5/weather?&q=ust-tarka
# City not found. Skipping...
# Processing Record 353 | Saint-Joseph
# https://api.openweathermap.org/data/2.5/weather?&q=saint-joseph
# Processing Record 354 | Oranjemund
# https://api.openweathermap.org/data/2.5/weather?&q=oranjemund
# Processing Record 355 | Lota
# https://api.openweathermap.org/data/2.5/weather?&q=lota
# Processing Record 356 | Saint-Louis
# https://api.openweathermap.org/data/2.5/weather?&q=saint-louis
# Processing Record 357 | Rybnaya Sloboda
# https://api.openweathermap.org/data/2.5/weather?&q=rybnaya sloboda
# Processing Record 358 | Coburg
# https://api.openweathermap.org/data/2.5/weather?&q=coburg
# Processing Record 359 | Yanam
# https://api.openweathermap.org/data/2.5/weather?&q=yanam
# Processing Record 360 | Mayo
# https://api.openweathermap.org/data/2.5/weather?&q=mayo
# Processing Record 361 | Sai Buri
# https://api.openweathermap.org/data/2.5/weather?&q=sai buri
# Processing Record 362 | Cabedelo
# https://api.openweathermap.org/data/2.5/weather?&q=cabedelo
# Processing Record 363 | Birao
# https://api.openweathermap.org/data/2.5/weather?&q=birao
# Processing Record 364 | Zabid
# https://api.openweathermap.org/data/2.5/weather?&q=zabid
# Processing Record 365 | Harper
# https://api.openweathermap.org/data/2.5/weather?&q=harper
# Processing Record 366 | Staraya Mayna
# https://api.openweathermap.org/data/2.5/weather?&q=staraya mayna
# Processing Record 367 | Yar-Sale
# https://api.openweathermap.org/data/2.5/weather?&q=yar-sale
# Processing Record 368 | Stokmarknes
# https://api.openweathermap.org/data/2.5/weather?&q=stokmarknes
# Processing Record 369 | Ancud
# https://api.openweathermap.org/data/2.5/weather?&q=ancud
# Processing Record 370 | Flores da Cunha
# https://api.openweathermap.org/data/2.5/weather?&q=flores da cunha
# Processing Record 371 | Alugan
# https://api.openweathermap.org/data/2.5/weather?&q=alugan
# City not found. Skipping...
# Processing Record 372 | Batticaloa
# https://api.openweathermap.org/data/2.5/weather?&q=batticaloa
# Processing Record 373 | Akureyri
# https://api.openweathermap.org/data/2.5/weather?&q=akureyri
# Processing Record 374 | Haimen
# https://api.openweathermap.org/data/2.5/weather?&q=haimen
# Processing Record 375 | Ta Khmau
# https://api.openweathermap.org/data/2.5/weather?&q=ta khmau
# Processing Record 376 | Matamoros
# https://api.openweathermap.org/data/2.5/weather?&q=matamoros
# Processing Record 377 | Loikaw
# https://api.openweathermap.org/data/2.5/weather?&q=loikaw
# Processing Record 378 | Maningrida
# https://api.openweathermap.org/data/2.5/weather?&q=maningrida
# Processing Record 379 | Zyryanka
# https://api.openweathermap.org/data/2.5/weather?&q=zyryanka
# Processing Record 380 | Albufeira
# https://api.openweathermap.org/data/2.5/weather?&q=albufeira
# Processing Record 381 | Samarai
# https://api.openweathermap.org/data/2.5/weather?&q=samarai
# Processing Record 382 | Pisco
# https://api.openweathermap.org/data/2.5/weather?&q=pisco
# Processing Record 383 | Faya
# https://api.openweathermap.org/data/2.5/weather?&q=faya
# Processing Record 384 | Los Llanos de Aridane
# https://api.openweathermap.org/data/2.5/weather?&q=los llanos de aridane
# Processing Record 385 | Ikom
# https://api.openweathermap.org/data/2.5/weather?&q=ikom
# Processing Record 386 | Praya
# https://api.openweathermap.org/data/2.5/weather?&q=praya
# City not found. Skipping...
# Processing Record 387 | Upington
# https://api.openweathermap.org/data/2.5/weather?&q=upington
# City not found. Skipping...
# Processing Record 388 | Carnduff
# https://api.openweathermap.org/data/2.5/weather?&q=carnduff
# Processing Record 389 | Laives
# https://api.openweathermap.org/data/2.5/weather?&q=laives
# Processing Record 390 | Maniitsoq
# https://api.openweathermap.org/data/2.5/weather?&q=maniitsoq
# Processing Record 391 | Sambava
# https://api.openweathermap.org/data/2.5/weather?&q=sambava
# Processing Record 392 | Viedma
# https://api.openweathermap.org/data/2.5/weather?&q=viedma
# Processing Record 393 | Tuatapere
# https://api.openweathermap.org/data/2.5/weather?&q=tuatapere
# City not found. Skipping...
# Processing Record 394 | Veraval
# https://api.openweathermap.org/data/2.5/weather?&q=veraval
# Processing Record 395 | Greenwood
# https://api.openweathermap.org/data/2.5/weather?&q=greenwood
# Processing Record 396 | Council Bluffs
# https://api.openweathermap.org/data/2.5/weather?&q=council bluffs
# Processing Record 397 | Lensk
# https://api.openweathermap.org/data/2.5/weather?&q=lensk
# Processing Record 398 | Cabra
# https://api.openweathermap.org/data/2.5/weather?&q=cabra
# Processing Record 399 | Aksu
# https://api.openweathermap.org/data/2.5/weather?&q=aksu
# Processing Record 400 | Kuryk
# https://api.openweathermap.org/data/2.5/weather?&q=kuryk
# Processing Record 401 | Tarakan
# https://api.openweathermap.org/data/2.5/weather?&q=tarakan
# Processing Record 402 | Alice Springs
# https://api.openweathermap.org/data/2.5/weather?&q=alice springs
# Processing Record 403 | Anton Lizardo
# https://api.openweathermap.org/data/2.5/weather?&q=anton lizardo
# Processing Record 404 | Faranah
# https://api.openweathermap.org/data/2.5/weather?&q=faranah
# Processing Record 405 | Fare
# https://api.openweathermap.org/data/2.5/weather?&q=fare
# City not found. Skipping...
# Processing Record 406 | San Quintin
# https://api.openweathermap.org/data/2.5/weather?&q=san quintin
# Processing Record 407 | Cayenne
# https://api.openweathermap.org/data/2.5/weather?&q=cayenne
# Processing Record 408 | Saint-Georges
# https://api.openweathermap.org/data/2.5/weather?&q=saint-georges
# Processing Record 409 | Pacific Grove
# https://api.openweathermap.org/data/2.5/weather?&q=pacific grove
# Processing Record 410 | Guzelyurt
# https://api.openweathermap.org/data/2.5/weather?&q=guzelyurt
# Processing Record 411 | Udachnyy
# https://api.openweathermap.org/data/2.5/weather?&q=udachnyy
# Processing Record 412 | Muborak
# https://api.openweathermap.org/data/2.5/weather?&q=muborak
# City not found. Skipping...
# Processing Record 413 | Le Port
# https://api.openweathermap.org/data/2.5/weather?&q=le port
# Processing Record 414 | Bulgan
# https://api.openweathermap.org/data/2.5/weather?&q=bulgan
# Processing Record 415 | Avera
# https://api.openweathermap.org/data/2.5/weather?&q=avera
# Processing Record 416 | Tibagi
# https://api.openweathermap.org/data/2.5/weather?&q=tibagi
# Processing Record 417 | Igrim
# https://api.openweathermap.org/data/2.5/weather?&q=igrim
# Processing Record 418 | Del Rio
# https://api.openweathermap.org/data/2.5/weather?&q=del rio
# Processing Record 419 | Tarko-Sale
# https://api.openweathermap.org/data/2.5/weather?&q=tarko-sale
# Processing Record 420 | Noyabrsk
# https://api.openweathermap.org/data/2.5/weather?&q=noyabrsk
# City not found. Skipping...
# Processing Record 421 | Nuuk
# https://api.openweathermap.org/data/2.5/weather?&q=nuuk
# Processing Record 422 | Tecoanapa
# https://api.openweathermap.org/data/2.5/weather?&q=tecoanapa
# Processing Record 423 | Telde
# https://api.openweathermap.org/data/2.5/weather?&q=telde
# Processing Record 424 | Heihe
# https://api.openweathermap.org/data/2.5/weather?&q=heihe
# City not found. Skipping...
# Processing Record 425 | Fairbanks
# https://api.openweathermap.org/data/2.5/weather?&q=fairbanks
# Processing Record 426 | Dzilam Gonzalez
# https://api.openweathermap.org/data/2.5/weather?&q=dzilam gonzalez
# Processing Record 427 | Iquique
# https://api.openweathermap.org/data/2.5/weather?&q=iquique
# Processing Record 428 | Kulhudhuffushi
# https://api.openweathermap.org/data/2.5/weather?&q=kulhudhuffushi
# Processing Record 429 | Sao Miguel
# https://api.openweathermap.org/data/2.5/weather?&q=sao miguel
# Processing Record 430 | Kamenka
# https://api.openweathermap.org/data/2.5/weather?&q=kamenka
# Processing Record 431 | Vila Franca do Campo
# https://api.openweathermap.org/data/2.5/weather?&q=vila franca do campo
# Processing Record 432 | Clyde River
# https://api.openweathermap.org/data/2.5/weather?&q=clyde river
# Processing Record 433 | Sijunjung
# https://api.openweathermap.org/data/2.5/weather?&q=sijunjung
# Processing Record 434 | Guaymas
# https://api.openweathermap.org/data/2.5/weather?&q=guaymas
# Processing Record 435 | Karachi
# https://api.openweathermap.org/data/2.5/weather?&q=karachi
# Processing Record 436 | Dingle
# https://api.openweathermap.org/data/2.5/weather?&q=dingle
# Processing Record 437 | Baracoa
# https://api.openweathermap.org/data/2.5/weather?&q=baracoa
# Processing Record 438 | Abha
# https://api.openweathermap.org/data/2.5/weather?&q=abha
# Processing Record 439 | Bergkamen
# https://api.openweathermap.org/data/2.5/weather?&q=bergkamen
# City not found. Skipping...
# Processing Record 440 | Burnham
# https://api.openweathermap.org/data/2.5/weather?&q=burnham
# Processing Record 441 | Zastron
# https://api.openweathermap.org/data/2.5/weather?&q=zastron
# Processing Record 442 | Cisnadie
# https://api.openweathermap.org/data/2.5/weather?&q=cisnadie
# City not found. Skipping...
# Processing Record 443 | Brigantine
# https://api.openweathermap.org/data/2.5/weather?&q=brigantine
# Processing Record 444 | Sarvar
# https://api.openweathermap.org/data/2.5/weather?&q=sarvar
# Processing Record 445 | Ossora
# https://api.openweathermap.org/data/2.5/weather?&q=ossora
# Processing Record 446 | Ambilobe
# https://api.openweathermap.org/data/2.5/weather?&q=ambilobe
# Processing Record 447 | Sechura
# https://api.openweathermap.org/data/2.5/weather?&q=sechura
# Processing Record 448 | Goderich
# https://api.openweathermap.org/data/2.5/weather?&q=goderich
# Processing Record 449 | Pontianak
# https://api.openweathermap.org/data/2.5/weather?&q=pontianak
# Processing Record 450 | Pombas
# https://api.openweathermap.org/data/2.5/weather?&q=pombas
# Processing Record 451 | Waupun
# https://api.openweathermap.org/data/2.5/weather?&q=waupun
# Processing Record 452 | Vanimo
# https://api.openweathermap.org/data/2.5/weather?&q=vanimo
# Processing Record 453 | Sur
# https://api.openweathermap.org/data/2.5/weather?&q=sur
# Processing Record 454 | Gravdal
# https://api.openweathermap.org/data/2.5/weather?&q=gravdal
# Processing Record 455 | Teguldet
# https://api.openweathermap.org/data/2.5/weather?&q=teguldet
# Processing Record 456 | Stonehaven
# https://api.openweathermap.org/data/2.5/weather?&q=stonehaven
# Processing Record 457 | Bridlington
# https://api.openweathermap.org/data/2.5/weather?&q=bridlington
# Processing Record 458 | Erenhot
# https://api.openweathermap.org/data/2.5/weather?&q=erenhot
# Processing Record 459 | Hamilton
# https://api.openweathermap.org/data/2.5/weather?&q=hamilton
# Processing Record 460 | Sorland
# https://api.openweathermap.org/data/2.5/weather?&q=sorland
# Processing Record 461 | Boyolangu
# https://api.openweathermap.org/data/2.5/weather?&q=boyolangu
# Processing Record 462 | Riberalta
# https://api.openweathermap.org/data/2.5/weather?&q=riberalta
# Processing Record 463 | Kununurra
# https://api.openweathermap.org/data/2.5/weather?&q=kununurra
# City not found. Skipping...
# Processing Record 464 | Tual
# https://api.openweathermap.org/data/2.5/weather?&q=tual
# Processing Record 465 | Tieli
# https://api.openweathermap.org/data/2.5/weather?&q=tieli
# Processing Record 466 | Miles City
# https://api.openweathermap.org/data/2.5/weather?&q=miles city
# Processing Record 467 | Kumphawapi
# https://api.openweathermap.org/data/2.5/weather?&q=kumphawapi
# Processing Record 468 | Jinka
# https://api.openweathermap.org/data/2.5/weather?&q=jinka
# Processing Record 469 | Morehead
# https://api.openweathermap.org/data/2.5/weather?&q=morehead
# Processing Record 470 | Horta
# https://api.openweathermap.org/data/2.5/weather?&q=horta
# Processing Record 471 | Beloha
# https://api.openweathermap.org/data/2.5/weather?&q=beloha
# Processing Record 472 | Seymchan
# https://api.openweathermap.org/data/2.5/weather?&q=seymchan
# Processing Record 473 | Wawa
# https://api.openweathermap.org/data/2.5/weather?&q=wawa
# Processing Record 474 | Bathsheba
# https://api.openweathermap.org/data/2.5/weather?&q=bathsheba
# Processing Record 475 | Skawina
# https://api.openweathermap.org/data/2.5/weather?&q=skawina
# Processing Record 476 | Verkhnyaya Inta
# https://api.openweathermap.org/data/2.5/weather?&q=verkhnyaya inta
# Processing Record 477 | Palmer
# https://api.openweathermap.org/data/2.5/weather?&q=palmer
# Processing Record 478 | Nanortalik
# https://api.openweathermap.org/data/2.5/weather?&q=nanortalik
# City not found. Skipping...
# Processing Record 479 | Port Hawkesbury
# https://api.openweathermap.org/data/2.5/weather?&q=port hawkesbury
# Processing Record 480 | Vagur
# https://api.openweathermap.org/data/2.5/weather?&q=vagur
# Processing Record 481 | Deputatskiy
# https://api.openweathermap.org/data/2.5/weather?&q=deputatskiy
# Processing Record 482 | Tarragona
# https://api.openweathermap.org/data/2.5/weather?&q=tarragona
# City not found. Skipping...
# Processing Record 483 | Xining
# https://api.openweathermap.org/data/2.5/weather?&q=xining
# City not found. Skipping...
# Processing Record 484 | Moose Factory
# https://api.openweathermap.org/data/2.5/weather?&q=moose factory
# Processing Record 485 | Tucuman
# https://api.openweathermap.org/data/2.5/weather?&q=tucuman
# Processing Record 486 | Norsup
# https://api.openweathermap.org/data/2.5/weather?&q=norsup
# City not found. Skipping...
# Processing Record 487 | Mwanza
# https://api.openweathermap.org/data/2.5/weather?&q=mwanza
# Processing Record 488 | Ngunguru
# https://api.openweathermap.org/data/2.5/weather?&q=ngunguru
# Processing Record 489 | Kupang
# https://api.openweathermap.org/data/2.5/weather?&q=kupang
# City not found. Skipping...
# Processing Record 490 | Luderitz
# https://api.openweathermap.org/data/2.5/weather?&q=luderitz
# Processing Record 491 | Ibra
# https://api.openweathermap.org/data/2.5/weather?&q=ibra
# Processing Record 492 | Kirakira
# https://api.openweathermap.org/data/2.5/weather?&q=kirakira
# Processing Record 493 | Kingston
# https://api.openweathermap.org/data/2.5/weather?&q=kingston
# Processing Record 494 | Big Rapids
# https://api.openweathermap.org/data/2.5/weather?&q=big rapids
# City not found. Skipping...
# Processing Record 495 | Kloulklubed
# https://api.openweathermap.org/data/2.5/weather?&q=kloulklubed
# Processing Record 496 | Shubarshi
# https://api.openweathermap.org/data/2.5/weather?&q=shubarshi
# Processing Record 497 | Petropavlovsk-Kamchatskiy
# https://api.openweathermap.org/data/2.5/weather?&q=petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 498 | Krasnyy Oktyabr
# https://api.openweathermap.org/data/2.5/weather?&q=krasnyy oktyabr
# Processing Record 499 | Urucara
# https://api.openweathermap.org/data/2.5/weather?&q=urucara
# Processing Record 500 | Charters Towers
# https://api.openweathermap.org/data/2.5/weather?&q=charters towers
# Processing Record 501 | Dukat
# https://api.openweathermap.org/data/2.5/weather?&q=dukat
# Processing Record 502 | Kedrovyy
# https://api.openweathermap.org/data/2.5/weather?&q=kedrovyy
# Processing Record 503 | Bonfim
# https://api.openweathermap.org/data/2.5/weather?&q=bonfim
# Processing Record 504 | Ayan
# https://api.openweathermap.org/data/2.5/weather?&q=ayan
# Processing Record 505 | Te Anau
# https://api.openweathermap.org/data/2.5/weather?&q=te anau
# Processing Record 506 | Toora-Khem
# https://api.openweathermap.org/data/2.5/weather?&q=toora-khem
# Processing Record 507 | Coos Bay
# https://api.openweathermap.org/data/2.5/weather?&q=coos bay
# Processing Record 508 | Acapulco
# https://api.openweathermap.org/data/2.5/weather?&q=acapulco
# Processing Record 509 | Verkhnyaya Toyma
# https://api.openweathermap.org/data/2.5/weather?&q=verkhnyaya toyma
# Processing Record 510 | Zhigansk
# https://api.openweathermap.org/data/2.5/weather?&q=zhigansk
# Processing Record 511 | Rundu
# https://api.openweathermap.org/data/2.5/weather?&q=rundu
# Processing Record 512 | Hendek
# https://api.openweathermap.org/data/2.5/weather?&q=hendek
# Processing Record 513 | Phan Thiet
# https://api.openweathermap.org/data/2.5/weather?&q=phan thiet
# Processing Record 514 | Trairi
# https://api.openweathermap.org/data/2.5/weather?&q=trairi
# Processing Record 515 | Pedernales
# https://api.openweathermap.org/data/2.5/weather?&q=pedernales
# Processing Record 516 | Homer
# https://api.openweathermap.org/data/2.5/weather?&q=homer
# Processing Record 517 | Bonthe
# https://api.openweathermap.org/data/2.5/weather?&q=bonthe
# Processing Record 518 | Sunnyside
# https://api.openweathermap.org/data/2.5/weather?&q=sunnyside
# City not found. Skipping...
# Processing Record 519 | Shelburne
# https://api.openweathermap.org/data/2.5/weather?&q=shelburne
# Processing Record 520 | Thabazimbi
# https://api.openweathermap.org/data/2.5/weather?&q=thabazimbi
# City not found. Skipping...
# Processing Record 521 | Poum
# https://api.openweathermap.org/data/2.5/weather?&q=poum
# Processing Record 522 | Iacu
# https://api.openweathermap.org/data/2.5/weather?&q=iacu
# Processing Record 523 | Atar
# https://api.openweathermap.org/data/2.5/weather?&q=atar
# Processing Record 524 | Khorinsk
# https://api.openweathermap.org/data/2.5/weather?&q=khorinsk
# Processing Record 525 | Bien Hoa
# https://api.openweathermap.org/data/2.5/weather?&q=bien hoa
# Processing Record 526 | Saint-Germain-de-Grantham
# https://api.openweathermap.org/data/2.5/weather?&q=saint-germain-de-grantham
# Processing Record 527 | Garowe
# https://api.openweathermap.org/data/2.5/weather?&q=garowe
# Processing Record 528 | Miracema do Tocantins
# https://api.openweathermap.org/data/2.5/weather?&q=miracema do tocantins
# Processing Record 529 | Stoughton
# https://api.openweathermap.org/data/2.5/weather?&q=stoughton
# Processing Record 530 | Sisophon
# https://api.openweathermap.org/data/2.5/weather?&q=sisophon
# Processing Record 531 | Mucuri
# https://api.openweathermap.org/data/2.5/weather?&q=mucuri
# Processing Record 532 | Glendive
# https://api.openweathermap.org/data/2.5/weather?&q=glendive
# Processing Record 533 | Nur
# https://api.openweathermap.org/data/2.5/weather?&q=nur
# Processing Record 534 | Caravelas
# https://api.openweathermap.org/data/2.5/weather?&q=caravelas
# Processing Record 535 | Douglas
# https://api.openweathermap.org/data/2.5/weather?&q=douglas
# Processing Record 536 | Buraydah
# https://api.openweathermap.org/data/2.5/weather?&q=buraydah
# Processing Record 537 | Yakeshi
# https://api.openweathermap.org/data/2.5/weather?&q=yakeshi
# Processing Record 538 | Kashira
# https://api.openweathermap.org/data/2.5/weather?&q=kashira
# Processing Record 539 | Lesnoye
# https://api.openweathermap.org/data/2.5/weather?&q=lesnoye
# Processing Record 540 | Shache
# https://api.openweathermap.org/data/2.5/weather?&q=shache
# City not found. Skipping...
# Processing Record 541 | Buchanan
# https://api.openweathermap.org/data/2.5/weather?&q=buchanan
# Processing Record 542 | Lianzhou
# https://api.openweathermap.org/data/2.5/weather?&q=lianzhou
# Processing Record 543 | Peterhead
# https://api.openweathermap.org/data/2.5/weather?&q=peterhead
# Processing Record 544 | Salta
# https://api.openweathermap.org/data/2.5/weather?&q=salta
# Processing Record 545 | Majene
# https://api.openweathermap.org/data/2.5/weather?&q=majene
# Processing Record 546 | Chiredzi
# https://api.openweathermap.org/data/2.5/weather?&q=chiredzi
# Processing Record 547 | Agadez
# https://api.openweathermap.org/data/2.5/weather?&q=agadez
# Processing Record 548 | Nhulunbuy
# https://api.openweathermap.org/data/2.5/weather?&q=nhulunbuy
# Processing Record 549 | Harbour Breton
# https://api.openweathermap.org/data/2.5/weather?&q=harbour breton
# Processing Record 550 | Qaqortoq
# https://api.openweathermap.org/data/2.5/weather?&q=qaqortoq
# Processing Record 551 | Okakarara
# https://api.openweathermap.org/data/2.5/weather?&q=okakarara
# City not found. Skipping...
# Processing Record 552 | Sao Sebastiao
# https://api.openweathermap.org/data/2.5/weather?&q=sao sebastiao
# Processing Record 553 | Duncan
# https://api.openweathermap.org/data/2.5/weather?&q=duncan
# Processing Record 554 | Talcahuano
# https://api.openweathermap.org/data/2.5/weather?&q=talcahuano
# Processing Record 555 | Valdivia
# https://api.openweathermap.org/data/2.5/weather?&q=valdivia
# Processing Record 556 | Nome
# https://api.openweathermap.org/data/2.5/weather?&q=nome
# Processing Record 557 | Saint-Denis
# https://api.openweathermap.org/data/2.5/weather?&q=saint-denis

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          557
# Cloudiness    557
# Country       557
# Date          557
# Humidity      557
# Lat           557
# Lng           557
# Max Temp      557
# Wind Speed    557
# dtype: int64

# %%
weatherpy_dict

# %%
# Save data frame to CSV
weather_data.to_csv("weather_data.csv")

# Display data frame head 
weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0   Saint John          90      CA  1570544031       100  45.28 -66.06
# 1         Naze         100      NG  1570544072        94   5.43   7.07
# 2    Mahebourg          75      MU  1570544073        69 -20.41  57.70
# 3      Ushuaia          75      AR  1570543835        84 -54.81 -68.31
# 4  Cleethorpes          40      GB  1570544074        63  53.56  -0.03
#
#    Max Temp  Wind Speed
# 0     13.33        2.60
# 1     23.31        2.82
# 2     23.33        7.20
# 3      3.00       13.90
# 4     16.11        9.30

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", edgecolor="black", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", edgecolor="black", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", edgecolor="black", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", edgecolor="black", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %%
#1. Maximum Temperature increases with latitude, reaches maximum when latitude is between 20 and 40 and then again decreases 
#as latitude increases
#2. Cities at higher latitude have higher humidity levels. Most of the cities having latitude between 0 and 60 have humidity 
# levels between  50 and 100.
#3. Cities at higher latitudes (less than 0) are more windy compared to cities at latitudes less than zero.
