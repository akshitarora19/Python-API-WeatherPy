# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
# %matplotlib notebook

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Output File (CSV)
output_data_file = "cities-Copy.csv"

# Exporting list of cities to csv file
with open (output_data_file, "w", newline='') as cities_file:
    city_data=csv.writer(cities_file, delimiter=",")
    for city in cities:
        city_data.writerow(city)

# %%
url= "https://api.openweathermap.org/data/2.5/weather?"
units="metric"

for city in cities:
    query_url = f"{url}appid={api_key}&units={units}&q={city}"

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    try:
        response = requests.get(f"{url}appid={api_key}&units={units}&q={city}").json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Tasiilaq
# https://api.openweathermap.org/data/2.5/weather?&q=tasiilaq
# Processing Record 2 | Rikitea
# https://api.openweathermap.org/data/2.5/weather?&q=rikitea
# Processing Record 3 | Bethel
# https://api.openweathermap.org/data/2.5/weather?&q=bethel
# Processing Record 4 | Yellowknife
# https://api.openweathermap.org/data/2.5/weather?&q=yellowknife
# Processing Record 5 | Hilo
# https://api.openweathermap.org/data/2.5/weather?&q=hilo
# Processing Record 6 | Ushuaia
# https://api.openweathermap.org/data/2.5/weather?&q=ushuaia
# Processing Record 7 | Salalah
# https://api.openweathermap.org/data/2.5/weather?&q=salalah
# Processing Record 8 | Pevek
# https://api.openweathermap.org/data/2.5/weather?&q=pevek
# Processing Record 9 | Thompson
# https://api.openweathermap.org/data/2.5/weather?&q=thompson
# Processing Record 10 | Mar del Plata
# https://api.openweathermap.org/data/2.5/weather?&q=mar del plata
# Processing Record 11 | Kurduvadi
# https://api.openweathermap.org/data/2.5/weather?&q=kurduvadi
# Processing Record 12 | Pompeu
# https://api.openweathermap.org/data/2.5/weather?&q=pompeu
# Processing Record 13 | Jamestown
# https://api.openweathermap.org/data/2.5/weather?&q=jamestown
# Processing Record 14 | Rawson
# https://api.openweathermap.org/data/2.5/weather?&q=rawson
# Processing Record 15 | Norman Wells
# https://api.openweathermap.org/data/2.5/weather?&q=norman wells
# Processing Record 16 | San Carlos de Bariloche
# https://api.openweathermap.org/data/2.5/weather?&q=san carlos de bariloche
# Processing Record 17 | Albany
# https://api.openweathermap.org/data/2.5/weather?&q=albany
# Processing Record 18 | Punta Arenas
# https://api.openweathermap.org/data/2.5/weather?&q=punta arenas
# Processing Record 19 | Puerto Madero
# https://api.openweathermap.org/data/2.5/weather?&q=puerto madero
# Processing Record 20 | Mataura
# https://api.openweathermap.org/data/2.5/weather?&q=mataura
# Processing Record 21 | Sitka
# https://api.openweathermap.org/data/2.5/weather?&q=sitka
# City not found. Skipping...
# Processing Record 22 | Katghora
# https://api.openweathermap.org/data/2.5/weather?&q=katghora
# Processing Record 23 | Tiksi
# https://api.openweathermap.org/data/2.5/weather?&q=tiksi
# Processing Record 24 | Dingle
# https://api.openweathermap.org/data/2.5/weather?&q=dingle
# Processing Record 25 | Hobart
# https://api.openweathermap.org/data/2.5/weather?&q=hobart
# Processing Record 26 | Puerto Escondido
# https://api.openweathermap.org/data/2.5/weather?&q=puerto escondido
# Processing Record 27 | Vanavara
# https://api.openweathermap.org/data/2.5/weather?&q=vanavara
# Processing Record 28 | Linhares
# https://api.openweathermap.org/data/2.5/weather?&q=linhares
# Processing Record 29 | Cherskiy
# https://api.openweathermap.org/data/2.5/weather?&q=cherskiy
# Processing Record 30 | Chokurdakh
# https://api.openweathermap.org/data/2.5/weather?&q=chokurdakh
# Processing Record 31 | Atuona
# https://api.openweathermap.org/data/2.5/weather?&q=atuona
# Processing Record 32 | Clyde River
# https://api.openweathermap.org/data/2.5/weather?&q=clyde river
# Processing Record 33 | Gonbad-e Qabus
# https://api.openweathermap.org/data/2.5/weather?&q=gonbad-e qabus
# Processing Record 34 | Puerto Ayora
# https://api.openweathermap.org/data/2.5/weather?&q=puerto ayora
# Processing Record 35 | Mbalmayo
# https://api.openweathermap.org/data/2.5/weather?&q=mbalmayo
# Processing Record 36 | Roros
# https://api.openweathermap.org/data/2.5/weather?&q=roros
# Processing Record 37 | Ballina
# https://api.openweathermap.org/data/2.5/weather?&q=ballina
# Processing Record 38 | Yarada
# https://api.openweathermap.org/data/2.5/weather?&q=yarada
# City not found. Skipping...
# Processing Record 39 | Ticuantepe
# https://api.openweathermap.org/data/2.5/weather?&q=ticuantepe
# Processing Record 40 | Hermanus
# https://api.openweathermap.org/data/2.5/weather?&q=hermanus
# Processing Record 41 | Zhezkazgan
# https://api.openweathermap.org/data/2.5/weather?&q=zhezkazgan
# Processing Record 42 | Plettenberg Bay
# https://api.openweathermap.org/data/2.5/weather?&q=plettenberg bay
# Processing Record 43 | Guangyuan
# https://api.openweathermap.org/data/2.5/weather?&q=guangyuan
# Processing Record 44 | East London
# https://api.openweathermap.org/data/2.5/weather?&q=east london
# Processing Record 45 | Plastun
# https://api.openweathermap.org/data/2.5/weather?&q=plastun
# City not found. Skipping...
# Processing Record 46 | Lixourion
# https://api.openweathermap.org/data/2.5/weather?&q=lixourion
# Processing Record 47 | Geraldton
# https://api.openweathermap.org/data/2.5/weather?&q=geraldton
# Processing Record 48 | Vaini
# https://api.openweathermap.org/data/2.5/weather?&q=vaini
# City not found. Skipping...
# Processing Record 49 | Port Alfred
# https://api.openweathermap.org/data/2.5/weather?&q=port alfred
# Processing Record 50 | Kapaa
# https://api.openweathermap.org/data/2.5/weather?&q=kapaa
# Processing Record 51 | Castro
# https://api.openweathermap.org/data/2.5/weather?&q=castro
# Processing Record 52 | Hays
# https://api.openweathermap.org/data/2.5/weather?&q=hays
# Processing Record 53 | Airai
# https://api.openweathermap.org/data/2.5/weather?&q=airai
# Processing Record 54 | Butaritari
# https://api.openweathermap.org/data/2.5/weather?&q=butaritari
# Processing Record 55 | Chililabombwe
# https://api.openweathermap.org/data/2.5/weather?&q=chililabombwe
# Processing Record 56 | Bluff
# https://api.openweathermap.org/data/2.5/weather?&q=bluff
# Processing Record 57 | Alofi
# https://api.openweathermap.org/data/2.5/weather?&q=alofi
# Processing Record 58 | Ribeira Grande
# https://api.openweathermap.org/data/2.5/weather?&q=ribeira grande
# Processing Record 59 | Aquidauana
# https://api.openweathermap.org/data/2.5/weather?&q=aquidauana
# Processing Record 60 | Karratha
# https://api.openweathermap.org/data/2.5/weather?&q=karratha
# Processing Record 61 | Alyangula
# https://api.openweathermap.org/data/2.5/weather?&q=alyangula
# City not found. Skipping...
# Processing Record 62 | New Norfolk
# https://api.openweathermap.org/data/2.5/weather?&q=new norfolk
# Processing Record 63 | Narsaq
# https://api.openweathermap.org/data/2.5/weather?&q=narsaq
# City not found. Skipping...
# Processing Record 64 | Paraibano
# https://api.openweathermap.org/data/2.5/weather?&q=paraibano
# Processing Record 65 | Thinadhoo
# https://api.openweathermap.org/data/2.5/weather?&q=thinadhoo
# Processing Record 66 | Wroclaw
# https://api.openweathermap.org/data/2.5/weather?&q=wroclaw
# Processing Record 67 | Auxerre
# https://api.openweathermap.org/data/2.5/weather?&q=auxerre
# Processing Record 68 | Kaitangata
# https://api.openweathermap.org/data/2.5/weather?&q=kaitangata
# Processing Record 69 | Faanui
# https://api.openweathermap.org/data/2.5/weather?&q=faanui
# Processing Record 70 | Tautira
# https://api.openweathermap.org/data/2.5/weather?&q=tautira
# Processing Record 71 | Ilulissat
# https://api.openweathermap.org/data/2.5/weather?&q=ilulissat
# City not found. Skipping...
# Processing Record 72 | Goderich
# https://api.openweathermap.org/data/2.5/weather?&q=goderich
# Processing Record 73 | Ahipara
# https://api.openweathermap.org/data/2.5/weather?&q=ahipara
# Processing Record 74 | Champerico
# https://api.openweathermap.org/data/2.5/weather?&q=champerico
# Processing Record 75 | Kasempa
# https://api.openweathermap.org/data/2.5/weather?&q=kasempa
# City not found. Skipping...
# Processing Record 76 | Cabo San Lucas
# https://api.openweathermap.org/data/2.5/weather?&q=cabo san lucas
# Processing Record 77 | Avarua
# https://api.openweathermap.org/data/2.5/weather?&q=avarua
# City not found. Skipping...
# Processing Record 78 | Arraial do Cabo
# https://api.openweathermap.org/data/2.5/weather?&q=arraial do cabo
# Processing Record 79 | Saint Anthony
# https://api.openweathermap.org/data/2.5/weather?&q=saint anthony
# Processing Record 80 | Fort-Shevchenko
# https://api.openweathermap.org/data/2.5/weather?&q=fort-shevchenko
# Processing Record 81 | Chuy
# https://api.openweathermap.org/data/2.5/weather?&q=chuy
# Processing Record 82 | Dabou
# https://api.openweathermap.org/data/2.5/weather?&q=dabou
# City not found. Skipping...
# Processing Record 83 | Kautokeino
# https://api.openweathermap.org/data/2.5/weather?&q=kautokeino
# Processing Record 84 | Rach Gia
# https://api.openweathermap.org/data/2.5/weather?&q=rach gia
# Processing Record 85 | Sur
# https://api.openweathermap.org/data/2.5/weather?&q=sur
# Processing Record 86 | Pachino
# https://api.openweathermap.org/data/2.5/weather?&q=pachino
# Processing Record 87 | Tuktoyaktuk
# https://api.openweathermap.org/data/2.5/weather?&q=tuktoyaktuk
# City not found. Skipping...
# Processing Record 88 | Dikson
# https://api.openweathermap.org/data/2.5/weather?&q=dikson
# Processing Record 89 | Naze
# https://api.openweathermap.org/data/2.5/weather?&q=naze
# Processing Record 90 | Severo-Kurilsk
# https://api.openweathermap.org/data/2.5/weather?&q=severo-kurilsk
# Processing Record 91 | Ulladulla
# https://api.openweathermap.org/data/2.5/weather?&q=ulladulla
# Processing Record 92 | Ponta do Sol
# https://api.openweathermap.org/data/2.5/weather?&q=ponta do sol
# Processing Record 93 | Port Lincoln
# https://api.openweathermap.org/data/2.5/weather?&q=port lincoln
# Processing Record 94 | Porto Nacional
# https://api.openweathermap.org/data/2.5/weather?&q=porto nacional
# Processing Record 95 | Busselton
# https://api.openweathermap.org/data/2.5/weather?&q=busselton
# Processing Record 96 | Mount Isa
# https://api.openweathermap.org/data/2.5/weather?&q=mount isa
# Processing Record 97 | Sainte-Rose
# https://api.openweathermap.org/data/2.5/weather?&q=sainte-rose
# Processing Record 98 | Khatanga
# https://api.openweathermap.org/data/2.5/weather?&q=khatanga
# Processing Record 99 | Rodez
# https://api.openweathermap.org/data/2.5/weather?&q=rodez
# Processing Record 100 | Marzuq
# https://api.openweathermap.org/data/2.5/weather?&q=marzuq
# Processing Record 101 | Tilichiki
# https://api.openweathermap.org/data/2.5/weather?&q=tilichiki
# Processing Record 102 | Mamburao
# https://api.openweathermap.org/data/2.5/weather?&q=mamburao
# Processing Record 103 | Kloulklubed
# https://api.openweathermap.org/data/2.5/weather?&q=kloulklubed
# Processing Record 104 | Saint-Philippe
# https://api.openweathermap.org/data/2.5/weather?&q=saint-philippe
# Processing Record 105 | Sao Joao dos Patos
# https://api.openweathermap.org/data/2.5/weather?&q=sao joao dos patos
# Processing Record 106 | Saskylakh
# https://api.openweathermap.org/data/2.5/weather?&q=saskylakh
# Processing Record 107 | Itarema
# https://api.openweathermap.org/data/2.5/weather?&q=itarema
# Processing Record 108 | Yining
# https://api.openweathermap.org/data/2.5/weather?&q=yining
# Processing Record 109 | Vila Franca do Campo
# https://api.openweathermap.org/data/2.5/weather?&q=vila franca do campo
# Processing Record 110 | Kovdor
# https://api.openweathermap.org/data/2.5/weather?&q=kovdor
# Processing Record 111 | Kavieng
# https://api.openweathermap.org/data/2.5/weather?&q=kavieng
# Processing Record 112 | Kearney
# https://api.openweathermap.org/data/2.5/weather?&q=kearney
# Processing Record 113 | Rundu
# https://api.openweathermap.org/data/2.5/weather?&q=rundu
# Processing Record 114 | Gizo
# https://api.openweathermap.org/data/2.5/weather?&q=gizo
# Processing Record 115 | Bambous Virieux
# https://api.openweathermap.org/data/2.5/weather?&q=bambous virieux
# Processing Record 116 | Nuzvid
# https://api.openweathermap.org/data/2.5/weather?&q=nuzvid
# Processing Record 117 | San Andres
# https://api.openweathermap.org/data/2.5/weather?&q=san andres
# Processing Record 118 | Manokwari
# https://api.openweathermap.org/data/2.5/weather?&q=manokwari
# Processing Record 119 | Carnarvon
# https://api.openweathermap.org/data/2.5/weather?&q=carnarvon
# Processing Record 120 | Upernavik
# https://api.openweathermap.org/data/2.5/weather?&q=upernavik
# City not found. Skipping...
# Processing Record 121 | Talnakh
# https://api.openweathermap.org/data/2.5/weather?&q=talnakh
# Processing Record 122 | Nikolskoye
# https://api.openweathermap.org/data/2.5/weather?&q=nikolskoye
# Processing Record 123 | Erzin
# https://api.openweathermap.org/data/2.5/weather?&q=erzin
# Processing Record 124 | Cabedelo
# https://api.openweathermap.org/data/2.5/weather?&q=cabedelo
# City not found. Skipping...
# Processing Record 125 | Leningradskiy
# https://api.openweathermap.org/data/2.5/weather?&q=leningradskiy
# Processing Record 126 | Catabola
# https://api.openweathermap.org/data/2.5/weather?&q=catabola
# Processing Record 127 | Xam Nua
# https://api.openweathermap.org/data/2.5/weather?&q=xam nua
# Processing Record 128 | Abu Dhabi
# https://api.openweathermap.org/data/2.5/weather?&q=abu dhabi
# Processing Record 129 | Kodiak
# https://api.openweathermap.org/data/2.5/weather?&q=kodiak
# Processing Record 130 | Freeport
# https://api.openweathermap.org/data/2.5/weather?&q=freeport
# City not found. Skipping...
# Processing Record 131 | Sosnowiec
# https://api.openweathermap.org/data/2.5/weather?&q=sosnowiec
# Processing Record 132 | Craig
# https://api.openweathermap.org/data/2.5/weather?&q=craig
# Processing Record 133 | Nishihara
# https://api.openweathermap.org/data/2.5/weather?&q=nishihara
# Processing Record 134 | Miramar
# https://api.openweathermap.org/data/2.5/weather?&q=miramar
# Processing Record 135 | Kostek
# https://api.openweathermap.org/data/2.5/weather?&q=kostek
# Processing Record 136 | Basco
# https://api.openweathermap.org/data/2.5/weather?&q=basco
# Processing Record 137 | Rosario
# https://api.openweathermap.org/data/2.5/weather?&q=rosario
# Processing Record 138 | Lewiston
# https://api.openweathermap.org/data/2.5/weather?&q=lewiston
# Processing Record 139 | Victoria
# https://api.openweathermap.org/data/2.5/weather?&q=victoria
# Processing Record 140 | Qaanaaq
# https://api.openweathermap.org/data/2.5/weather?&q=qaanaaq
# Processing Record 141 | Lorengau
# https://api.openweathermap.org/data/2.5/weather?&q=lorengau
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 142 | Coquimbo
# https://api.openweathermap.org/data/2.5/weather?&q=coquimbo
# Processing Record 143 | Mumford
# https://api.openweathermap.org/data/2.5/weather?&q=mumford
# Processing Record 144 | Ranavav
# https://api.openweathermap.org/data/2.5/weather?&q=ranavav
# Processing Record 145 | Barrow
# https://api.openweathermap.org/data/2.5/weather?&q=barrow
# Processing Record 146 | Vanimo
# https://api.openweathermap.org/data/2.5/weather?&q=vanimo
# Processing Record 147 | Georgetown
# https://api.openweathermap.org/data/2.5/weather?&q=georgetown
# Processing Record 148 | Husavik
# https://api.openweathermap.org/data/2.5/weather?&q=husavik
# Processing Record 149 | Bredasdorp
# https://api.openweathermap.org/data/2.5/weather?&q=bredasdorp
# Processing Record 150 | Erenhot
# https://api.openweathermap.org/data/2.5/weather?&q=erenhot
# City not found. Skipping...
# Processing Record 151 | Hamilton
# https://api.openweathermap.org/data/2.5/weather?&q=hamilton
# Processing Record 152 | Chany
# https://api.openweathermap.org/data/2.5/weather?&q=chany
# Processing Record 153 | Berlevag
# https://api.openweathermap.org/data/2.5/weather?&q=berlevag
# Processing Record 154 | Wenling
# https://api.openweathermap.org/data/2.5/weather?&q=wenling
# Processing Record 155 | Mayo
# https://api.openweathermap.org/data/2.5/weather?&q=mayo
# Processing Record 156 | Teguise
# https://api.openweathermap.org/data/2.5/weather?&q=teguise
# Processing Record 157 | The Valley
# https://api.openweathermap.org/data/2.5/weather?&q=the valley
# Processing Record 158 | Port Hardy
# https://api.openweathermap.org/data/2.5/weather?&q=port hardy
# Processing Record 159 | Constitucion
# https://api.openweathermap.org/data/2.5/weather?&q=constitucion
# Processing Record 160 | Ola
# https://api.openweathermap.org/data/2.5/weather?&q=ola
# Processing Record 161 | Toamasina
# https://api.openweathermap.org/data/2.5/weather?&q=toamasina
# Processing Record 162 | Waipawa
# https://api.openweathermap.org/data/2.5/weather?&q=waipawa
# City not found. Skipping...
# Processing Record 163 | Beaverlodge
# https://api.openweathermap.org/data/2.5/weather?&q=beaverlodge
# Processing Record 164 | Shache
# https://api.openweathermap.org/data/2.5/weather?&q=shache
# Processing Record 165 | Progreso
# https://api.openweathermap.org/data/2.5/weather?&q=progreso
# Processing Record 166 | Port Hedland
# https://api.openweathermap.org/data/2.5/weather?&q=port hedland
# Processing Record 167 | Gamba
# https://api.openweathermap.org/data/2.5/weather?&q=gamba
# Processing Record 168 | Evensk
# https://api.openweathermap.org/data/2.5/weather?&q=evensk
# Processing Record 169 | Mungaoli
# https://api.openweathermap.org/data/2.5/weather?&q=mungaoli
# Processing Record 170 | Saint-Augustin
# https://api.openweathermap.org/data/2.5/weather?&q=saint-augustin
# Processing Record 171 | Tabas
# https://api.openweathermap.org/data/2.5/weather?&q=tabas
# Processing Record 172 | Muros
# https://api.openweathermap.org/data/2.5/weather?&q=muros
# Processing Record 173 | Komsomolskiy
# https://api.openweathermap.org/data/2.5/weather?&q=komsomolskiy
# Processing Record 174 | Cape Town
# https://api.openweathermap.org/data/2.5/weather?&q=cape town
# Processing Record 175 | Taoudenni
# https://api.openweathermap.org/data/2.5/weather?&q=taoudenni
# City not found. Skipping...
# Processing Record 176 | Kavaratti
# https://api.openweathermap.org/data/2.5/weather?&q=kavaratti
# City not found. Skipping...
# Processing Record 177 | Isangel
# https://api.openweathermap.org/data/2.5/weather?&q=isangel
# Processing Record 178 | Velyka Oleksandrivka
# https://api.openweathermap.org/data/2.5/weather?&q=velyka oleksandrivka
# Processing Record 179 | Carauari
# https://api.openweathermap.org/data/2.5/weather?&q=carauari
# Processing Record 180 | Yoichi
# https://api.openweathermap.org/data/2.5/weather?&q=yoichi
# City not found. Skipping...
# Processing Record 181 | Haicheng
# https://api.openweathermap.org/data/2.5/weather?&q=haicheng
# Processing Record 182 | Petropavlovsk-Kamchatskiy
# https://api.openweathermap.org/data/2.5/weather?&q=petropavlovsk-kamchatskiy
# Processing Record 183 | Umm Lajj
# https://api.openweathermap.org/data/2.5/weather?&q=umm lajj
# Processing Record 184 | Dreux
# https://api.openweathermap.org/data/2.5/weather?&q=dreux
# Processing Record 185 | Ancud
# https://api.openweathermap.org/data/2.5/weather?&q=ancud
# Processing Record 186 | Pangnirtung
# https://api.openweathermap.org/data/2.5/weather?&q=pangnirtung
# Processing Record 187 | Vila do Maio
# https://api.openweathermap.org/data/2.5/weather?&q=vila do maio
# City not found. Skipping...
# Processing Record 188 | Douglas
# https://api.openweathermap.org/data/2.5/weather?&q=douglas
# Processing Record 189 | Tirat Karmel
# https://api.openweathermap.org/data/2.5/weather?&q=tirat karmel
# Processing Record 190 | Vila Velha
# https://api.openweathermap.org/data/2.5/weather?&q=vila velha
# Processing Record 191 | Belokurikha
# https://api.openweathermap.org/data/2.5/weather?&q=belokurikha
# City not found. Skipping...
# Processing Record 192 | Praxedis Guerrero
# https://api.openweathermap.org/data/2.5/weather?&q=praxedis guerrero
# Processing Record 193 | Opuwo
# https://api.openweathermap.org/data/2.5/weather?&q=opuwo
# Processing Record 194 | Half Moon Bay
# https://api.openweathermap.org/data/2.5/weather?&q=half moon bay
# Processing Record 195 | Berezovyy
# https://api.openweathermap.org/data/2.5/weather?&q=berezovyy
# Processing Record 196 | Cidreira
# https://api.openweathermap.org/data/2.5/weather?&q=cidreira
# Processing Record 197 | Pochutla
# https://api.openweathermap.org/data/2.5/weather?&q=pochutla
# Processing Record 198 | Mahebourg
# https://api.openweathermap.org/data/2.5/weather?&q=mahebourg
# Processing Record 199 | Helong
# https://api.openweathermap.org/data/2.5/weather?&q=helong
# Processing Record 200 | San Antonio
# https://api.openweathermap.org/data/2.5/weather?&q=san antonio
# Processing Record 201 | Albion
# https://api.openweathermap.org/data/2.5/weather?&q=albion
# Processing Record 202 | Igrim
# https://api.openweathermap.org/data/2.5/weather?&q=igrim
# Processing Record 203 | Valparaiso
# https://api.openweathermap.org/data/2.5/weather?&q=valparaiso
# Processing Record 204 | Nabire
# https://api.openweathermap.org/data/2.5/weather?&q=nabire
# Processing Record 205 | Kishi
# https://api.openweathermap.org/data/2.5/weather?&q=kishi
# City not found. Skipping...
# Processing Record 206 | Namibe
# https://api.openweathermap.org/data/2.5/weather?&q=namibe
# City not found. Skipping...
# Processing Record 207 | Sao Filipe
# https://api.openweathermap.org/data/2.5/weather?&q=sao filipe
# Processing Record 208 | Shimoda
# https://api.openweathermap.org/data/2.5/weather?&q=shimoda
# Processing Record 209 | Hasaki
# https://api.openweathermap.org/data/2.5/weather?&q=hasaki
# City not found. Skipping...
# Processing Record 210 | Lasa
# https://api.openweathermap.org/data/2.5/weather?&q=lasa
# Processing Record 211 | Burns Lake
# https://api.openweathermap.org/data/2.5/weather?&q=burns lake
# Processing Record 212 | Boquira
# https://api.openweathermap.org/data/2.5/weather?&q=boquira
# Processing Record 213 | Dakar
# https://api.openweathermap.org/data/2.5/weather?&q=dakar
# Processing Record 214 | Vestmannaeyjar
# https://api.openweathermap.org/data/2.5/weather?&q=vestmannaeyjar
# Processing Record 215 | Kurchum
# https://api.openweathermap.org/data/2.5/weather?&q=kurchum
# Processing Record 216 | Port Shepstone
# https://api.openweathermap.org/data/2.5/weather?&q=port shepstone
# Processing Record 217 | Luanda
# https://api.openweathermap.org/data/2.5/weather?&q=luanda
# Processing Record 218 | Lompoc
# https://api.openweathermap.org/data/2.5/weather?&q=lompoc
# Processing Record 219 | Saldanha
# https://api.openweathermap.org/data/2.5/weather?&q=saldanha
# Processing Record 220 | Diego de Almagro
# https://api.openweathermap.org/data/2.5/weather?&q=diego de almagro
# Processing Record 221 | Akdepe
# https://api.openweathermap.org/data/2.5/weather?&q=akdepe
# Processing Record 222 | Zetel
# https://api.openweathermap.org/data/2.5/weather?&q=zetel
# Processing Record 223 | Souillac
# https://api.openweathermap.org/data/2.5/weather?&q=souillac
# Processing Record 224 | Huarmey
# https://api.openweathermap.org/data/2.5/weather?&q=huarmey
# Processing Record 225 | Esperance
# https://api.openweathermap.org/data/2.5/weather?&q=esperance
# Processing Record 226 | Kahului
# https://api.openweathermap.org/data/2.5/weather?&q=kahului
# Processing Record 227 | Vostok
# https://api.openweathermap.org/data/2.5/weather?&q=vostok
# Processing Record 228 | Luau
# https://api.openweathermap.org/data/2.5/weather?&q=luau
# Processing Record 229 | Quirinopolis
# https://api.openweathermap.org/data/2.5/weather?&q=quirinopolis
# Processing Record 230 | Khartoum
# https://api.openweathermap.org/data/2.5/weather?&q=khartoum
# City not found. Skipping...
# Processing Record 231 | Maniitsoq
# https://api.openweathermap.org/data/2.5/weather?&q=maniitsoq
# Processing Record 232 | Lebu
# https://api.openweathermap.org/data/2.5/weather?&q=lebu
# City not found. Skipping...
# Processing Record 233 | Areia Branca
# https://api.openweathermap.org/data/2.5/weather?&q=areia branca
# Processing Record 234 | Okhotsk
# https://api.openweathermap.org/data/2.5/weather?&q=okhotsk
# Processing Record 235 | Joacaba
# https://api.openweathermap.org/data/2.5/weather?&q=joacaba
# Processing Record 236 | Amilly
# https://api.openweathermap.org/data/2.5/weather?&q=amilly
# Processing Record 237 | Nanortalik
# https://api.openweathermap.org/data/2.5/weather?&q=nanortalik
# Processing Record 238 | Rasskazovo
# https://api.openweathermap.org/data/2.5/weather?&q=rasskazovo
# Processing Record 239 | Newport
# https://api.openweathermap.org/data/2.5/weather?&q=newport
# Processing Record 240 | La Rioja
# https://api.openweathermap.org/data/2.5/weather?&q=la rioja
# Processing Record 241 | Sumbe
# https://api.openweathermap.org/data/2.5/weather?&q=sumbe
# Processing Record 242 | Teocaltiche
# https://api.openweathermap.org/data/2.5/weather?&q=teocaltiche
# Processing Record 243 | Provideniya
# https://api.openweathermap.org/data/2.5/weather?&q=provideniya
# City not found. Skipping...
# Processing Record 244 | Shirokiy
# https://api.openweathermap.org/data/2.5/weather?&q=shirokiy
# Processing Record 245 | Port Elizabeth
# https://api.openweathermap.org/data/2.5/weather?&q=port elizabeth
# Processing Record 246 | Bandarbeyla
# https://api.openweathermap.org/data/2.5/weather?&q=bandarbeyla
# Processing Record 247 | Changji
# https://api.openweathermap.org/data/2.5/weather?&q=changji
# Processing Record 248 | Mecca
# https://api.openweathermap.org/data/2.5/weather?&q=mecca
# Processing Record 249 | Portland
# https://api.openweathermap.org/data/2.5/weather?&q=portland
# City not found. Skipping...
# Processing Record 250 | Katherine
# https://api.openweathermap.org/data/2.5/weather?&q=katherine
# Processing Record 251 | Wattegama
# https://api.openweathermap.org/data/2.5/weather?&q=wattegama
# Processing Record 252 | Yenagoa
# https://api.openweathermap.org/data/2.5/weather?&q=yenagoa
# Processing Record 253 | Teguldet
# https://api.openweathermap.org/data/2.5/weather?&q=teguldet
# Processing Record 254 | Torbay
# https://api.openweathermap.org/data/2.5/weather?&q=torbay
# Processing Record 255 | Praia
# https://api.openweathermap.org/data/2.5/weather?&q=praia
# Processing Record 256 | Yaan
# https://api.openweathermap.org/data/2.5/weather?&q=yaan
# Processing Record 257 | Sulangan
# https://api.openweathermap.org/data/2.5/weather?&q=sulangan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 258 | Novi Iskar
# https://api.openweathermap.org/data/2.5/weather?&q=novi iskar
# Processing Record 259 | Malinyi
# https://api.openweathermap.org/data/2.5/weather?&q=malinyi
# Processing Record 260 | Tessalit
# https://api.openweathermap.org/data/2.5/weather?&q=tessalit
# City not found. Skipping...
# Processing Record 261 | Ponta Delgada
# https://api.openweathermap.org/data/2.5/weather?&q=ponta delgada
# Processing Record 262 | Belaya Gora
# https://api.openweathermap.org/data/2.5/weather?&q=belaya gora
# Processing Record 263 | San Rafael
# https://api.openweathermap.org/data/2.5/weather?&q=san rafael
# Processing Record 264 | San Patricio
# https://api.openweathermap.org/data/2.5/weather?&q=san patricio
# Processing Record 265 | Lata
# https://api.openweathermap.org/data/2.5/weather?&q=lata
# Processing Record 266 | Caravelas
# https://api.openweathermap.org/data/2.5/weather?&q=caravelas
# Processing Record 267 | Ostrovnoy
# https://api.openweathermap.org/data/2.5/weather?&q=ostrovnoy
# Processing Record 268 | Nata
# https://api.openweathermap.org/data/2.5/weather?&q=nata
# Processing Record 269 | Sisimiut
# https://api.openweathermap.org/data/2.5/weather?&q=sisimiut
# Processing Record 270 | Sechura
# https://api.openweathermap.org/data/2.5/weather?&q=sechura
# Processing Record 271 | Kitimat
# https://api.openweathermap.org/data/2.5/weather?&q=kitimat
# Processing Record 272 | Birao
# https://api.openweathermap.org/data/2.5/weather?&q=birao
# Processing Record 273 | Tres Arroyos
# https://api.openweathermap.org/data/2.5/weather?&q=tres arroyos
# Processing Record 274 | Xiuyan
# https://api.openweathermap.org/data/2.5/weather?&q=xiuyan
# Processing Record 275 | Naryan-Mar
# https://api.openweathermap.org/data/2.5/weather?&q=naryan-mar
# Processing Record 276 | Shar
# https://api.openweathermap.org/data/2.5/weather?&q=shar
# Processing Record 277 | Inyonga
# https://api.openweathermap.org/data/2.5/weather?&q=inyonga
# Processing Record 278 | Rovaniemi
# https://api.openweathermap.org/data/2.5/weather?&q=rovaniemi
# Processing Record 279 | Codrington
# https://api.openweathermap.org/data/2.5/weather?&q=codrington
# Processing Record 280 | Rorvik
# https://api.openweathermap.org/data/2.5/weather?&q=rorvik
# Processing Record 281 | Phan Thiet
# https://api.openweathermap.org/data/2.5/weather?&q=phan thiet
# Processing Record 282 | Ngunguru
# https://api.openweathermap.org/data/2.5/weather?&q=ngunguru
# Processing Record 283 | Kizema
# https://api.openweathermap.org/data/2.5/weather?&q=kizema
# City not found. Skipping...
# Processing Record 284 | Illapel
# https://api.openweathermap.org/data/2.5/weather?&q=illapel
# Processing Record 285 | Jiexiu
# https://api.openweathermap.org/data/2.5/weather?&q=jiexiu
# Processing Record 286 | Iaciara
# https://api.openweathermap.org/data/2.5/weather?&q=iaciara
# Processing Record 287 | Bend
# https://api.openweathermap.org/data/2.5/weather?&q=bend
# Processing Record 288 | Lunino
# https://api.openweathermap.org/data/2.5/weather?&q=lunino
# Processing Record 289 | La Reforma
# https://api.openweathermap.org/data/2.5/weather?&q=la reforma
# Processing Record 290 | Tuatapere
# https://api.openweathermap.org/data/2.5/weather?&q=tuatapere
# Processing Record 291 | Penapolis
# https://api.openweathermap.org/data/2.5/weather?&q=penapolis
# Processing Record 292 | Longyearbyen
# https://api.openweathermap.org/data/2.5/weather?&q=longyearbyen
# Processing Record 293 | Kudahuvadhoo
# https://api.openweathermap.org/data/2.5/weather?&q=kudahuvadhoo
# Processing Record 294 | Sinnamary
# https://api.openweathermap.org/data/2.5/weather?&q=sinnamary
# Processing Record 295 | Kayerkan
# https://api.openweathermap.org/data/2.5/weather?&q=kayerkan
# Processing Record 296 | Bassano
# https://api.openweathermap.org/data/2.5/weather?&q=bassano
# Processing Record 297 | Ambilobe
# https://api.openweathermap.org/data/2.5/weather?&q=ambilobe
# Processing Record 298 | Anton Lizardo
# https://api.openweathermap.org/data/2.5/weather?&q=anton lizardo
# Processing Record 299 | Rabo de Peixe
# https://api.openweathermap.org/data/2.5/weather?&q=rabo de peixe
# Processing Record 300 | Binzhou
# https://api.openweathermap.org/data/2.5/weather?&q=binzhou
# Processing Record 301 | Zambezi
# https://api.openweathermap.org/data/2.5/weather?&q=zambezi
# Processing Record 302 | Harlingen
# https://api.openweathermap.org/data/2.5/weather?&q=harlingen
# Processing Record 303 | Bastia
# https://api.openweathermap.org/data/2.5/weather?&q=bastia
# Processing Record 304 | Liepaja
# https://api.openweathermap.org/data/2.5/weather?&q=liepaja
# City not found. Skipping...
# Processing Record 305 | Quelimane
# https://api.openweathermap.org/data/2.5/weather?&q=quelimane
# City not found. Skipping...
# Processing Record 306 | Tura
# https://api.openweathermap.org/data/2.5/weather?&q=tura
# Processing Record 307 | Touros
# https://api.openweathermap.org/data/2.5/weather?&q=touros
# Processing Record 308 | Kailua
# https://api.openweathermap.org/data/2.5/weather?&q=kailua
# Processing Record 309 | Simao
# https://api.openweathermap.org/data/2.5/weather?&q=simao
# Processing Record 310 | Fort Smith
# https://api.openweathermap.org/data/2.5/weather?&q=fort smith
# Processing Record 311 | Saint George
# https://api.openweathermap.org/data/2.5/weather?&q=saint george
# Processing Record 312 | Pisco
# https://api.openweathermap.org/data/2.5/weather?&q=pisco
# Processing Record 313 | Ziro
# https://api.openweathermap.org/data/2.5/weather?&q=ziro
# Processing Record 314 | Beloha
# https://api.openweathermap.org/data/2.5/weather?&q=beloha
# Processing Record 315 | Athabasca
# https://api.openweathermap.org/data/2.5/weather?&q=athabasca
# Processing Record 316 | Tocopilla
# https://api.openweathermap.org/data/2.5/weather?&q=tocopilla
# Processing Record 317 | Natal
# https://api.openweathermap.org/data/2.5/weather?&q=natal
# Processing Record 318 | Tecpan
# https://api.openweathermap.org/data/2.5/weather?&q=tecpan
# Processing Record 319 | Armeria
# https://api.openweathermap.org/data/2.5/weather?&q=armeria
# Processing Record 320 | Cabo Rojo
# https://api.openweathermap.org/data/2.5/weather?&q=cabo rojo
# Processing Record 321 | Takoradi
# https://api.openweathermap.org/data/2.5/weather?&q=takoradi
# Processing Record 322 | Milos
# https://api.openweathermap.org/data/2.5/weather?&q=milos
# Processing Record 323 | Kidal
# https://api.openweathermap.org/data/2.5/weather?&q=kidal
# Processing Record 324 | Bathsheba
# https://api.openweathermap.org/data/2.5/weather?&q=bathsheba
# Processing Record 325 | Puerto Madryn
# https://api.openweathermap.org/data/2.5/weather?&q=puerto madryn
# Processing Record 326 | Comodoro Rivadavia
# https://api.openweathermap.org/data/2.5/weather?&q=comodoro rivadavia
# Processing Record 327 | Havelock
# https://api.openweathermap.org/data/2.5/weather?&q=havelock
# Processing Record 328 | Sundsvall
# https://api.openweathermap.org/data/2.5/weather?&q=sundsvall
# Processing Record 329 | Cotonou
# https://api.openweathermap.org/data/2.5/weather?&q=cotonou
# Processing Record 330 | Cochrane
# https://api.openweathermap.org/data/2.5/weather?&q=cochrane
# Processing Record 331 | Lesnoye
# https://api.openweathermap.org/data/2.5/weather?&q=lesnoye
# Processing Record 332 | Hobyo
# https://api.openweathermap.org/data/2.5/weather?&q=hobyo
# Processing Record 333 | Moerai
# https://api.openweathermap.org/data/2.5/weather?&q=moerai
# Processing Record 334 | Camabatela
# https://api.openweathermap.org/data/2.5/weather?&q=camabatela
# Processing Record 335 | Grindavik
# https://api.openweathermap.org/data/2.5/weather?&q=grindavik
# Processing Record 336 | Nouadhibou
# https://api.openweathermap.org/data/2.5/weather?&q=nouadhibou
# Processing Record 337 | Ankang
# https://api.openweathermap.org/data/2.5/weather?&q=ankang
# Processing Record 338 | La Ronge
# https://api.openweathermap.org/data/2.5/weather?&q=la ronge
# Processing Record 339 | Rindal
# https://api.openweathermap.org/data/2.5/weather?&q=rindal
# Processing Record 340 | Bonavista
# https://api.openweathermap.org/data/2.5/weather?&q=bonavista
# Processing Record 341 | Timon
# https://api.openweathermap.org/data/2.5/weather?&q=timon
# Processing Record 342 | College
# https://api.openweathermap.org/data/2.5/weather?&q=college
# Processing Record 343 | Beziers
# https://api.openweathermap.org/data/2.5/weather?&q=beziers
# Processing Record 344 | Katsuura
# https://api.openweathermap.org/data/2.5/weather?&q=katsuura
# Processing Record 345 | Mirnyy
# https://api.openweathermap.org/data/2.5/weather?&q=mirnyy
# Processing Record 346 | Vaitape
# https://api.openweathermap.org/data/2.5/weather?&q=vaitape
# Processing Record 347 | Dicabisagan
# https://api.openweathermap.org/data/2.5/weather?&q=dicabisagan
# Processing Record 348 | Avera
# https://api.openweathermap.org/data/2.5/weather?&q=avera
# Processing Record 349 | Hirara
# https://api.openweathermap.org/data/2.5/weather?&q=hirara
# Processing Record 350 | Key Largo
# https://api.openweathermap.org/data/2.5/weather?&q=key largo
# Processing Record 351 | Laguna
# https://api.openweathermap.org/data/2.5/weather?&q=laguna
# Processing Record 352 | Marsa Matruh
# https://api.openweathermap.org/data/2.5/weather?&q=marsa matruh
# Processing Record 353 | Samarai
# https://api.openweathermap.org/data/2.5/weather?&q=samarai
# Processing Record 354 | Nemuro
# https://api.openweathermap.org/data/2.5/weather?&q=nemuro
# City not found. Skipping...
# Processing Record 355 | Nome
# https://api.openweathermap.org/data/2.5/weather?&q=nome
# Processing Record 356 | Zhigansk
# https://api.openweathermap.org/data/2.5/weather?&q=zhigansk
# Processing Record 357 | Sidi Ali
# https://api.openweathermap.org/data/2.5/weather?&q=sidi ali
# Processing Record 358 | Navahrudak
# https://api.openweathermap.org/data/2.5/weather?&q=navahrudak
# Processing Record 359 | Marrakesh
# https://api.openweathermap.org/data/2.5/weather?&q=marrakesh
# Processing Record 360 | Banda Aceh
# https://api.openweathermap.org/data/2.5/weather?&q=banda aceh
# Processing Record 361 | Brae
# https://api.openweathermap.org/data/2.5/weather?&q=brae
# Processing Record 362 | Pangai
# https://api.openweathermap.org/data/2.5/weather?&q=pangai
# Processing Record 363 | Haines Junction
# https://api.openweathermap.org/data/2.5/weather?&q=haines junction
# Processing Record 364 | Douentza
# https://api.openweathermap.org/data/2.5/weather?&q=douentza
# Processing Record 365 | Salinas
# https://api.openweathermap.org/data/2.5/weather?&q=salinas
# Processing Record 366 | Bandar
# https://api.openweathermap.org/data/2.5/weather?&q=bandar
# Processing Record 367 | Ronne
# https://api.openweathermap.org/data/2.5/weather?&q=ronne
# Processing Record 368 | Limoeiro do Ajuru
# https://api.openweathermap.org/data/2.5/weather?&q=limoeiro do ajuru
# Processing Record 369 | Rome
# https://api.openweathermap.org/data/2.5/weather?&q=roma
# Processing Record 370 | Fuerte Olimpo
# https://api.openweathermap.org/data/2.5/weather?&q=fuerte olimpo
# Processing Record 371 | Panuco
# https://api.openweathermap.org/data/2.5/weather?&q=panuco
# Processing Record 372 | Kaka
# https://api.openweathermap.org/data/2.5/weather?&q=kaka
# Processing Record 373 | Rocha
# https://api.openweathermap.org/data/2.5/weather?&q=rocha
# Processing Record 374 | Huancavelica
# https://api.openweathermap.org/data/2.5/weather?&q=huancavelica
# Processing Record 375 | Rosetta
# https://api.openweathermap.org/data/2.5/weather?&q=rosetta
# Processing Record 376 | Kapit
# https://api.openweathermap.org/data/2.5/weather?&q=kapit
# City not found. Skipping...
# Processing Record 377 | Chegdomyn
# https://api.openweathermap.org/data/2.5/weather?&q=chegdomyn
# Processing Record 378 | Dharchula
# https://api.openweathermap.org/data/2.5/weather?&q=dharchula
# City not found. Skipping...
# Processing Record 379 | Biak
# https://api.openweathermap.org/data/2.5/weather?&q=biak
# City not found. Skipping...
# Processing Record 380 | Hornepayne
# https://api.openweathermap.org/data/2.5/weather?&q=hornepayne
# Processing Record 381 | Jaisalmer
# https://api.openweathermap.org/data/2.5/weather?&q=jaisalmer
# Processing Record 382 | Mogadishu
# https://api.openweathermap.org/data/2.5/weather?&q=mogadishu
# Processing Record 383 | Fereydunshahr
# https://api.openweathermap.org/data/2.5/weather?&q=fereydunshahr
# Processing Record 384 | Dunedin
# https://api.openweathermap.org/data/2.5/weather?&q=dunedin
# Processing Record 385 | Yulara
# https://api.openweathermap.org/data/2.5/weather?&q=yulara
# Processing Record 386 | Tottori
# https://api.openweathermap.org/data/2.5/weather?&q=tottori
# Processing Record 387 | Cumberland
# https://api.openweathermap.org/data/2.5/weather?&q=cumberland
# Processing Record 388 | Nhulunbuy
# https://api.openweathermap.org/data/2.5/weather?&q=nhulunbuy
# Processing Record 389 | Luderitz
# https://api.openweathermap.org/data/2.5/weather?&q=luderitz
# Processing Record 390 | Camacha
# https://api.openweathermap.org/data/2.5/weather?&q=camacha
# Processing Record 391 | Cockburn Town
# https://api.openweathermap.org/data/2.5/weather?&q=cockburn town
# Processing Record 392 | Quatre Cocos
# https://api.openweathermap.org/data/2.5/weather?&q=quatre cocos
# Processing Record 393 | Begunitsy
# https://api.openweathermap.org/data/2.5/weather?&q=begunitsy
# Processing Record 394 | Altay
# https://api.openweathermap.org/data/2.5/weather?&q=altay
# Processing Record 395 | Cordoba
# https://api.openweathermap.org/data/2.5/weather?&q=cordoba
# Processing Record 396 | Buraydah
# https://api.openweathermap.org/data/2.5/weather?&q=buraydah
# Processing Record 397 | Jizan
# https://api.openweathermap.org/data/2.5/weather?&q=jizan
# Processing Record 398 | Superior
# https://api.openweathermap.org/data/2.5/weather?&q=superior
# Processing Record 399 | Kamaris
# https://api.openweathermap.org/data/2.5/weather?&q=kamaris
# Processing Record 400 | Jalu
# https://api.openweathermap.org/data/2.5/weather?&q=jalu
# Processing Record 401 | Rochelle
# https://api.openweathermap.org/data/2.5/weather?&q=rochelle
# Processing Record 402 | Pacific Grove
# https://api.openweathermap.org/data/2.5/weather?&q=pacific grove
# Processing Record 403 | Aykhal
# https://api.openweathermap.org/data/2.5/weather?&q=aykhal
# Processing Record 404 | Hay River
# https://api.openweathermap.org/data/2.5/weather?&q=hay river
# Processing Record 405 | Mehamn
# https://api.openweathermap.org/data/2.5/weather?&q=mehamn
# Processing Record 406 | Juneau
# https://api.openweathermap.org/data/2.5/weather?&q=juneau
# Processing Record 407 | Teya
# https://api.openweathermap.org/data/2.5/weather?&q=teya
# Processing Record 408 | Braganca
# https://api.openweathermap.org/data/2.5/weather?&q=braganca
# Processing Record 409 | Halmaj
# https://api.openweathermap.org/data/2.5/weather?&q=halmaj
# Processing Record 410 | Pangkalanbuun
# https://api.openweathermap.org/data/2.5/weather?&q=pangkalanbuun
# Processing Record 411 | Port-Gentil
# https://api.openweathermap.org/data/2.5/weather?&q=port-gentil
# Processing Record 412 | Ippy
# https://api.openweathermap.org/data/2.5/weather?&q=ippy
# Processing Record 413 | Alice Town
# https://api.openweathermap.org/data/2.5/weather?&q=alice town
# Processing Record 414 | Flers
# https://api.openweathermap.org/data/2.5/weather?&q=flers
# Processing Record 415 | Papara
# https://api.openweathermap.org/data/2.5/weather?&q=papara
# Processing Record 416 | Slave Lake
# https://api.openweathermap.org/data/2.5/weather?&q=slave lake
# Processing Record 417 | Mato Verde
# https://api.openweathermap.org/data/2.5/weather?&q=mato verde
# Processing Record 418 | Sistranda
# https://api.openweathermap.org/data/2.5/weather?&q=sistranda
# Processing Record 419 | Hambantota
# https://api.openweathermap.org/data/2.5/weather?&q=hambantota
# Processing Record 420 | Caarapo
# https://api.openweathermap.org/data/2.5/weather?&q=caarapo
# Processing Record 421 | Marystown
# https://api.openweathermap.org/data/2.5/weather?&q=marystown
# City not found. Skipping...
# Processing Record 422 | Rio Gallegos
# https://api.openweathermap.org/data/2.5/weather?&q=rio gallegos
# Processing Record 423 | Hithadhoo
# https://api.openweathermap.org/data/2.5/weather?&q=hithadhoo
# Processing Record 424 | Kozhevnikovo
# https://api.openweathermap.org/data/2.5/weather?&q=kozhevnikovo
# Processing Record 425 | Sao Joao da Barra
# https://api.openweathermap.org/data/2.5/weather?&q=sao joao da barra
# Processing Record 426 | Apozol
# https://api.openweathermap.org/data/2.5/weather?&q=apozol
# Processing Record 427 | Lagoa
# https://api.openweathermap.org/data/2.5/weather?&q=lagoa
# Processing Record 428 | Boende
# https://api.openweathermap.org/data/2.5/weather?&q=boende
# Processing Record 429 | Port Macquarie
# https://api.openweathermap.org/data/2.5/weather?&q=port macquarie
# Processing Record 430 | Ishinomaki
# https://api.openweathermap.org/data/2.5/weather?&q=ishinomaki
# City not found. Skipping...
# Processing Record 431 | Mizque
# https://api.openweathermap.org/data/2.5/weather?&q=mizque
# Processing Record 432 | San Cristobal
# https://api.openweathermap.org/data/2.5/weather?&q=san cristobal
# Processing Record 433 | Bukachacha
# https://api.openweathermap.org/data/2.5/weather?&q=bukachacha
# Processing Record 434 | Kyela
# https://api.openweathermap.org/data/2.5/weather?&q=kyela
# Processing Record 435 | Ketchikan
# https://api.openweathermap.org/data/2.5/weather?&q=ketchikan
# Processing Record 436 | Muli
# https://api.openweathermap.org/data/2.5/weather?&q=muli
# Processing Record 437 | Kaseda
# https://api.openweathermap.org/data/2.5/weather?&q=kaseda
# Processing Record 438 | Oussouye
# https://api.openweathermap.org/data/2.5/weather?&q=oussouye
# Processing Record 439 | Fare
# https://api.openweathermap.org/data/2.5/weather?&q=fare
# Processing Record 440 | Ternate
# https://api.openweathermap.org/data/2.5/weather?&q=ternate
# Processing Record 441 | Camacupa
# https://api.openweathermap.org/data/2.5/weather?&q=camacupa
# Processing Record 442 | Charters Towers
# https://api.openweathermap.org/data/2.5/weather?&q=charters towers
# Processing Record 443 | Tshikapa
# https://api.openweathermap.org/data/2.5/weather?&q=tshikapa
# Processing Record 444 | Roald
# https://api.openweathermap.org/data/2.5/weather?&q=roald
# Processing Record 445 | Wewak
# https://api.openweathermap.org/data/2.5/weather?&q=wewak
# Processing Record 446 | Taybad
# https://api.openweathermap.org/data/2.5/weather?&q=taybad
# Processing Record 447 | Hazorasp
# https://api.openweathermap.org/data/2.5/weather?&q=hazorasp
# Processing Record 448 | Jasper
# https://api.openweathermap.org/data/2.5/weather?&q=jasper
# Processing Record 449 | Kamina
# https://api.openweathermap.org/data/2.5/weather?&q=kamina
# Processing Record 450 | Kangaatsiaq
# https://api.openweathermap.org/data/2.5/weather?&q=kangaatsiaq
# City not found. Skipping...
# Processing Record 451 | Oksfjord
# https://api.openweathermap.org/data/2.5/weather?&q=oksfjord
# Processing Record 452 | Palmer
# https://api.openweathermap.org/data/2.5/weather?&q=palmer
# Processing Record 453 | Bueno Brandao
# https://api.openweathermap.org/data/2.5/weather?&q=bueno brandao
# Processing Record 454 | Ciudad Bolivar
# https://api.openweathermap.org/data/2.5/weather?&q=ciudad bolivar
# Processing Record 455 | Hami
# https://api.openweathermap.org/data/2.5/weather?&q=hami
# Processing Record 456 | Desnogorsk
# https://api.openweathermap.org/data/2.5/weather?&q=desnogorsk
# City not found. Skipping...
# Processing Record 457 | Utrera
# https://api.openweathermap.org/data/2.5/weather?&q=utrera
# Processing Record 458 | Huanren
# https://api.openweathermap.org/data/2.5/weather?&q=huanren
# Processing Record 459 | Aragats
# https://api.openweathermap.org/data/2.5/weather?&q=aragats
# Processing Record 460 | Borba
# https://api.openweathermap.org/data/2.5/weather?&q=borba
# Processing Record 461 | Masuda
# https://api.openweathermap.org/data/2.5/weather?&q=masuda
# Processing Record 462 | Baruun-Urt
# https://api.openweathermap.org/data/2.5/weather?&q=baruun-urt
# Processing Record 463 | Pasighat
# https://api.openweathermap.org/data/2.5/weather?&q=pasighat
# Processing Record 464 | Kruisfontein
# https://api.openweathermap.org/data/2.5/weather?&q=kruisfontein
# Processing Record 465 | Yar-Sale
# https://api.openweathermap.org/data/2.5/weather?&q=yar-sale
# Processing Record 466 | Faya
# https://api.openweathermap.org/data/2.5/weather?&q=faya
# Processing Record 467 | Arshan
# https://api.openweathermap.org/data/2.5/weather?&q=arshan
# Processing Record 468 | Altea
# https://api.openweathermap.org/data/2.5/weather?&q=altea
# Processing Record 469 | Sedro-Woolley
# https://api.openweathermap.org/data/2.5/weather?&q=sedro-woolley
# Processing Record 470 | Lisakovsk
# https://api.openweathermap.org/data/2.5/weather?&q=lisakovsk
# Processing Record 471 | Kieta
# https://api.openweathermap.org/data/2.5/weather?&q=kieta
# Processing Record 472 | Corcoran
# https://api.openweathermap.org/data/2.5/weather?&q=corcoran
# City not found. Skipping...
# Processing Record 473 | Murgab
# https://api.openweathermap.org/data/2.5/weather?&q=murgab
# Processing Record 474 | Sept-Iles
# https://api.openweathermap.org/data/2.5/weather?&q=sept-iles
# Processing Record 475 | Wanaka
# https://api.openweathermap.org/data/2.5/weather?&q=wanaka
# Processing Record 476 | Aklavik
# https://api.openweathermap.org/data/2.5/weather?&q=aklavik
# Processing Record 477 | Srednekolymsk
# https://api.openweathermap.org/data/2.5/weather?&q=srednekolymsk
# Processing Record 478 | Acapulco
# https://api.openweathermap.org/data/2.5/weather?&q=acapulco
# Processing Record 479 | Morant Bay
# https://api.openweathermap.org/data/2.5/weather?&q=morant bay
# Processing Record 480 | Udgir
# https://api.openweathermap.org/data/2.5/weather?&q=udgir
# Processing Record 481 | Galesong
# https://api.openweathermap.org/data/2.5/weather?&q=galesong
# Processing Record 482 | Tiarei
# https://api.openweathermap.org/data/2.5/weather?&q=tiarei
# Processing Record 483 | Dunmore Town
# https://api.openweathermap.org/data/2.5/weather?&q=dunmore town
# Processing Record 484 | Zhaodong
# https://api.openweathermap.org/data/2.5/weather?&q=zhaodong
# Processing Record 485 | Ust-Omchug
# https://api.openweathermap.org/data/2.5/weather?&q=ust-omchug
# Processing Record 486 | North Branch
# https://api.openweathermap.org/data/2.5/weather?&q=north branch
# Processing Record 487 | Santa Cruz
# https://api.openweathermap.org/data/2.5/weather?&q=santa cruz
# City not found. Skipping...
# Processing Record 488 | Mokhsogollokh
# https://api.openweathermap.org/data/2.5/weather?&q=mokhsogollokh
# Processing Record 489 | Starobaltachevo
# https://api.openweathermap.org/data/2.5/weather?&q=starobaltachevo
# Processing Record 490 | Fortuna
# https://api.openweathermap.org/data/2.5/weather?&q=fortuna
# Processing Record 491 | Arkhangelsk
# https://api.openweathermap.org/data/2.5/weather?&q=arkhangelsk
# Processing Record 492 | Tucurui
# https://api.openweathermap.org/data/2.5/weather?&q=tucurui
# Processing Record 493 | Lapus
# https://api.openweathermap.org/data/2.5/weather?&q=lapus
# Processing Record 494 | Marienburg
# https://api.openweathermap.org/data/2.5/weather?&q=marienburg
# Processing Record 495 | Etaples
# https://api.openweathermap.org/data/2.5/weather?&q=etaples
# Processing Record 496 | Libreville
# https://api.openweathermap.org/data/2.5/weather?&q=libreville
# Processing Record 497 | Liverpool
# https://api.openweathermap.org/data/2.5/weather?&q=liverpool
# Processing Record 498 | Noumea
# https://api.openweathermap.org/data/2.5/weather?&q=noumea
# City not found. Skipping...
# Processing Record 499 | Elk Grove
# https://api.openweathermap.org/data/2.5/weather?&q=elk grove
# Processing Record 500 | Hongjiang
# https://api.openweathermap.org/data/2.5/weather?&q=hongjiang
# City not found. Skipping...
# Processing Record 501 | Bima
# https://api.openweathermap.org/data/2.5/weather?&q=bima
# Processing Record 502 | Leshukonskoye
# https://api.openweathermap.org/data/2.5/weather?&q=leshukonskoye
# Processing Record 503 | Atkinson
# https://api.openweathermap.org/data/2.5/weather?&q=atkinson
# Processing Record 504 | Margate
# https://api.openweathermap.org/data/2.5/weather?&q=margate
# Processing Record 505 | Araouane
# https://api.openweathermap.org/data/2.5/weather?&q=araouane
# Processing Record 506 | Namatanai
# https://api.openweathermap.org/data/2.5/weather?&q=namatanai
# Processing Record 507 | Kommunisticheskiy
# https://api.openweathermap.org/data/2.5/weather?&q=kommunisticheskiy
# Processing Record 508 | Kochubey
# https://api.openweathermap.org/data/2.5/weather?&q=kochubey
# Processing Record 509 | Krasnogorsk
# https://api.openweathermap.org/data/2.5/weather?&q=krasnogorsk
# City not found. Skipping...
# Processing Record 510 | Bratsk
# https://api.openweathermap.org/data/2.5/weather?&q=bratsk
# Processing Record 511 | Bereda
# https://api.openweathermap.org/data/2.5/weather?&q=bereda
# City not found. Skipping...
# Processing Record 512 | Broadstairs
# https://api.openweathermap.org/data/2.5/weather?&q=broadstairs
# Processing Record 513 | Juba
# https://api.openweathermap.org/data/2.5/weather?&q=juba
# Processing Record 514 | Taltal
# https://api.openweathermap.org/data/2.5/weather?&q=taltal
# Processing Record 515 | Asyut
# https://api.openweathermap.org/data/2.5/weather?&q=asyut
# Processing Record 516 | Iroquois Falls
# https://api.openweathermap.org/data/2.5/weather?&q=iroquois falls
# Processing Record 517 | Gorontalo
# https://api.openweathermap.org/data/2.5/weather?&q=gorontalo
# Processing Record 518 | Ust-Ishim
# https://api.openweathermap.org/data/2.5/weather?&q=ust-ishim
# Processing Record 519 | Zyryanka
# https://api.openweathermap.org/data/2.5/weather?&q=zyryanka
# Processing Record 520 | Rognan
# https://api.openweathermap.org/data/2.5/weather?&q=rognan
# Processing Record 521 | Hovd
# https://api.openweathermap.org/data/2.5/weather?&q=hovd
# Processing Record 522 | Winona
# https://api.openweathermap.org/data/2.5/weather?&q=winona
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 523 | Ndola
# https://api.openweathermap.org/data/2.5/weather?&q=ndola
# Processing Record 524 | Cayenne
# https://api.openweathermap.org/data/2.5/weather?&q=cayenne
# Processing Record 525 | Caconda
# https://api.openweathermap.org/data/2.5/weather?&q=caconda
# Processing Record 526 | Tirumullaivasal
# https://api.openweathermap.org/data/2.5/weather?&q=tirumullaivasal
# Processing Record 527 | Port Blair
# https://api.openweathermap.org/data/2.5/weather?&q=port blair
# Processing Record 528 | Klaksvik
# https://api.openweathermap.org/data/2.5/weather?&q=klaksvik
# City not found. Skipping...
# Processing Record 529 | Bemidji
# https://api.openweathermap.org/data/2.5/weather?&q=bemidji
# Processing Record 530 | Mount Gambier
# https://api.openweathermap.org/data/2.5/weather?&q=mount gambier
# Processing Record 531 | Uruzgan
# https://api.openweathermap.org/data/2.5/weather?&q=uruzgan
# Processing Record 532 | Sabha
# https://api.openweathermap.org/data/2.5/weather?&q=sabha
# Processing Record 533 | Aginskoye
# https://api.openweathermap.org/data/2.5/weather?&q=aginskoye
# Processing Record 534 | Saint-Joseph
# https://api.openweathermap.org/data/2.5/weather?&q=saint-joseph
# City not found. Skipping...
# Processing Record 535 | Rio Verde de Mato Grosso
# https://api.openweathermap.org/data/2.5/weather?&q=rio verde de mato grosso
# Processing Record 536 | Iberia
# https://api.openweathermap.org/data/2.5/weather?&q=iberia
# Processing Record 537 | Bull Savanna
# https://api.openweathermap.org/data/2.5/weather?&q=bull savanna
# Processing Record 538 | Colac
# https://api.openweathermap.org/data/2.5/weather?&q=colac
# City not found. Skipping...
# Processing Record 539 | Kang
# https://api.openweathermap.org/data/2.5/weather?&q=kang
# Processing Record 540 | Kayes
# https://api.openweathermap.org/data/2.5/weather?&q=kayes
# City not found. Skipping...
# Processing Record 541 | Jaguaribe
# https://api.openweathermap.org/data/2.5/weather?&q=jaguaribe
# Processing Record 542 | Oriximina
# https://api.openweathermap.org/data/2.5/weather?&q=oriximina
# Processing Record 543 | Dauphin
# https://api.openweathermap.org/data/2.5/weather?&q=dauphin
# Processing Record 544 | Grand-Santi
# https://api.openweathermap.org/data/2.5/weather?&q=grand-santi
# Processing Record 545 | Jablah
# https://api.openweathermap.org/data/2.5/weather?&q=jablah
# Processing Record 546 | Mangan
# https://api.openweathermap.org/data/2.5/weather?&q=mangan
# Processing Record 547 | Atar
# https://api.openweathermap.org/data/2.5/weather?&q=atar
# Processing Record 548 | Myanaung
# https://api.openweathermap.org/data/2.5/weather?&q=myanaung
# Processing Record 549 | Maryborough
# https://api.openweathermap.org/data/2.5/weather?&q=maryborough
# Processing Record 550 | Asheboro
# https://api.openweathermap.org/data/2.5/weather?&q=asheboro
# Processing Record 551 | Cortez
# https://api.openweathermap.org/data/2.5/weather?&q=cortez
# Processing Record 552 | Batagay-Alyta
# https://api.openweathermap.org/data/2.5/weather?&q=batagay-alyta
# Processing Record 553 | Pozo Colorado
# https://api.openweathermap.org/data/2.5/weather?&q=pozo colorado
# Processing Record 554 | Padang
# https://api.openweathermap.org/data/2.5/weather?&q=padang
# Processing Record 555 | Egvekinot
# https://api.openweathermap.org/data/2.5/weather?&q=egvekinot
# Processing Record 556 | Charlestown
# https://api.openweathermap.org/data/2.5/weather?&q=charlestown
# Processing Record 557 | Lanzhou
# https://api.openweathermap.org/data/2.5/weather?&q=lanzhou
# Processing Record 558 | Juigalpa
# https://api.openweathermap.org/data/2.5/weather?&q=juigalpa
# Processing Record 559 | Oeiras
# https://api.openweathermap.org/data/2.5/weather?&q=oeiras
# Processing Record 560 | Senanga
# https://api.openweathermap.org/data/2.5/weather?&q=senanga
# Processing Record 561 | Verkhnyaya Inta
# https://api.openweathermap.org/data/2.5/weather?&q=verkhnyaya inta
# Processing Record 562 | Betsiamites
# https://api.openweathermap.org/data/2.5/weather?&q=betsiamites
# Processing Record 563 | Saint-Georges
# https://api.openweathermap.org/data/2.5/weather?&q=saint-georges
# Processing Record 564 | Rivas
# https://api.openweathermap.org/data/2.5/weather?&q=rivas
# Processing Record 565 | Richards Bay
# https://api.openweathermap.org/data/2.5/weather?&q=richards bay
# Processing Record 566 | Komatipoort
# https://api.openweathermap.org/data/2.5/weather?&q=komatipoort
# Processing Record 567 | Presidente Dutra
# https://api.openweathermap.org/data/2.5/weather?&q=presidente dutra
# Processing Record 568 | Aktau
# https://api.openweathermap.org/data/2.5/weather?&q=aktau
# Processing Record 569 | Lavrentiya
# https://api.openweathermap.org/data/2.5/weather?&q=lavrentiya

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          569
# Cloudiness    569
# Country       569
# Date          569
# Humidity      569
# Lat           569
# Lng           569
# Max Temp      569
# Wind Speed    569
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv("weather_data.csv")

# Display data frame head 
weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Tasiilaq          73      GL  1562715621        93  65.61  -37.64
# 1      Rikitea          47      PF  1562715621        84 -23.12 -134.97
# 2       Bethel           1      US  1562715622        57  60.79 -161.76
# 3  Yellowknife          75      CA  1562715475        54  62.45 -114.38
# 4         Hilo          75      US  1562715421        62  19.71 -155.08
#
#    Max Temp  Wind Speed
# 0      3.00        2.60
# 1     23.05       10.37
# 2     26.00        4.10
# 3     15.00        4.10
# 4     29.00        3.10

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", edgecolor="black", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", edgecolor="black", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", edgecolor="black", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", edgecolor="black", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %%
#1. Maximum Temperature increases with latitude, reaches maximum when latitude is between 20 and 40 and then again decreases 
#as latitude increases
#2. Cities at higher latitude have higher humidity levels. Most of the cities having latitude between 0 and 60 have humidity 
# levels between  50 and 100.
#3. Cities at higher latitudes (less than 0) are more windy compared to cities at latitudes less than zero.
